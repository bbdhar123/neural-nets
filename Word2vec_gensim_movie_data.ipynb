# %% [markdown]
# ### Load Gensim Library

# %%
# !pip install gensim
# Out:
# Collecting gensim
#   Downloading https://files.pythonhosted.org/packages/27/a4/d10c0acc8528d838cda5eede0ee9c784caa598dbf40bd0911ff8d067a7eb/gensim-3.6.0-cp36-cp36m-manylinux1_x86_64.whl (23.6MB)
#     100% |████████████████████████████████| 23.6MB 1.3MB/s
# Requirement already satisfied: six>=1.5.0 in /usr/local/lib/python3.6/dist-packages (from gensim) (1.11.0)
# Collecting smart-open>=1.2.1 (from gensim)
#   Downloading https://files.pythonhosted.org/packages/4b/1f/6f27e3682124de63ac97a0a5876da6186de6c19410feab66c1543afab055/smart_open-1.7.1.tar.gz
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.6/dist-packages (from gensim) (0.19.1)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.6/dist-packages (from gensim) (1.14.6)
# Collecting boto>=2.32 (from smart-open>=1.2.1->gensim)
#   Downloading https://files.pythonhosted.org/packages/23/10/c0b78c27298029e4454a472a1919bde20cb182dab1662cec7f2ca1dcc523/boto-2.49.0-py2.py3-none-any.whl (1.4MB)
#     100% |████████████████████████████████| 1.4MB 13.6MB/s
# Collecting bz2file (from smart-open>=1.2.1->gensim)
#   Downloading https://files.pythonhosted.org/packages/61/39/122222b5e85cd41c391b68a99ee296584b2a2d1d233e7ee32b4532384f2d/bz2file-0.98.tar.gz
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from smart-open>=1.2.1->gensim) (2.18.4)
# Collecting boto3 (from smart-open>=1.2.1->gensim)
#   Downloading https://files.pythonhosted.org/packages/7a/7e/fe8faa29e771a09c528ee70e1fd9b317006021c48311ecccc78c22ebe739/boto3-1.9.37-py2.py3-none-any.whl (128kB)
#     100% |████████████████████████████████| 133kB 25.7MB/s
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.2.1->gensim) (2.6)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.2.1->gensim) (3.0.4)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.2.1->gensim) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.2.1->gensim) (2018.10.15)
# Collecting jmespath<1.0.0,>=0.7.1 (from boto3->smart-open>=1.2.1->gensim)
#   Downloading https://files.pythonhosted.org/packages/b7/31/05c8d001f7f87f0f07289a5fc0fc3832e9a57f2dbd4d3b0fee70e0d51365/jmespath-0.9.3-py2.py3-none-any.whl
# Collecting s3transfer<0.2.0,>=0.1.10 (from boto3->smart-open>=1.2.1->gensim)
#   Downloading https://files.pythonhosted.org/packages/d7/14/2a0004d487464d120c9fb85313a75cd3d71a7506955be458eebfe19a6b1d/s3transfer-0.1.13-py2.py3-none-any.whl (59kB)
#     100% |████████████████████████████████| 61kB 19.2MB/s
# Collecting botocore<1.13.0,>=1.12.37 (from boto3->smart-open>=1.2.1->gensim)
#   Downloading https://files.pythonhosted.org/packages/d0/35/1461771f778b67984a75a9853a2b3ed25e65a4345e669a81b50c67c930ab/botocore-1.12.37-py2.py3-none-any.whl (4.7MB)
#     100% |████████████████████████████████| 4.7MB 1.1MB/s
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1; python_version >= "2.7" in /usr/local/lib/python3.6/dist-packages (from botocore<1.13.0,>=1.12.37->boto3->smart-open>=1.2.1->gensim) (2.5.3)
# Collecting docutils>=0.10 (from botocore<1.13.0,>=1.12.37->boto3->smart-open>=1.2.1->gensim)
#   Downloading https://files.pythonhosted.org/packages/36/fa/08e9e6e0e3cbd1d362c3bbee8d01d0aedb2155c4ac112b19ef3cae8eed8d/docutils-0.14-py3-none-any.whl (543kB)
#     100% |████████████████████████████████| 552kB 22.3MB/s
# Building wheels for collected packages: smart-open, bz2file
# done
#   Stored in directory: /root/.cache/pip/wheels/23/00/44/e5b939f7a80c04e32297dbd6d96fa3065af89ecf57e2b5f89f
# done
#   Stored in directory: /root/.cache/pip/wheels/81/75/d6/e1317bf09bf1af5a30befc2a007869fa6e1f516b8f7c591cb9
# Successfully built smart-open bz2file
# Installing collected packages: boto, bz2file, jmespath, docutils, botocore, s3transfer, boto3, smart-open, gensim
# Successfully installed boto-2.49.0 boto3-1.9.37 botocore-1.12.37 bz2file-0.98 docutils-0.14 gensim-3.6.0 jmespath-0.9.3 s3transfer-0.1.13 smart-open-1.7.1

# %%
import gensim

# %%
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', 
                    level=logging.INFO)

# %%
# !ls
# Out:
# adc.json  labeledTrainData.tsv	sample_data  unlabeledTrainData.tsv

# %% [markdown]
# ### Load Text Data

# %%
import pandas as pd
df = pd.read_csv('unlabeledTrainData.tsv', header=0, delimiter="\t", quoting=3)

print('Number of examples in Dataset: ', df.shape)
df.head()
# Out:
# Number of examples in Dataset:  (50000, 2)
#           id                                             review
# 0   "9999_0"  "Watching Time Chasers, it obvious that it was...
# 1  "45057_0"  "I saw this film about 20 years ago and rememb...
# 2  "15561_0"  "Minor Spoilers<br /><br />In New York, Joan B...
# 3   "7161_0"  "I went to see this film with a great deal of ...
# 4  "43971_0"  "Yes, I agree with everyone on this site this ...

# %% [markdown]
# ### Function to Clean up data

# %%
import re, string

def clean_str(string):
  """
  String cleaning before vectorization
  """
  try:    
    string = re.sub(r'^https?:\/\/<>.*[\r\n]*', '', string, flags=re.MULTILINE)
    string = re.sub(r"[^A-Za-z]", " ", string)         
    words = string.strip().lower().split()    
    words = [w for w in words if len(w)>=1]
    return " ".join(words)	
  except:
    return ""

# %% [markdown]
# ### Clean the Data using routine above

# %%
df['clean_review'] = df['review'].apply(clean_str)
df.head()
# Out:
#           id                                             review  \
# 0   "9999_0"  "Watching Time Chasers, it obvious that it was...
# 1  "45057_0"  "I saw this film about 20 years ago and rememb...
# 2  "15561_0"  "Minor Spoilers<br /><br />In New York, Joan B...
# 3   "7161_0"  "I went to see this film with a great deal of ...
# 4  "43971_0"  "Yes, I agree with everyone on this site this ...
#
#                                         clean_review
# 0  watching time chasers it obvious that it was m...
# 1  i saw this film about years ago and remember i...
# 2  minor spoilers br br in new york joan barnard ...
# 3  i went to see this film with a great deal of e...
# 4  yes i agree with everyone on this site this mo...

# %% [markdown]
# ### Convert Review to a Word List

# %%
#List to hold all words in each review
documents = []

#Iterate over each review
for doc in df['clean_review']:
    documents.append(doc.split(' '))

print(len(documents))
print(documents[0])
# Out:
# 50000
# ['watching', 'time', 'chasers', 'it', 'obvious', 'that', 'it', 'was', 'made', 'by', 'a', 'bunch', 'of', 'friends', 'maybe', 'they', 'were', 'sitting', 'around', 'one', 'day', 'in', 'film', 'school', 'and', 'said', 'hey', 'let', 's', 'pool', 'our', 'money', 'together', 'and', 'make', 'a', 'really', 'bad', 'movie', 'or', 'something', 'like', 'that', 'what', 'ever', 'they', 'said', 'they', 'still', 'ended', 'up', 'making', 'a', 'really', 'bad', 'movie', 'dull', 'story', 'bad', 'script', 'lame', 'acting', 'poor', 'cinematography', 'bottom', 'of', 'the', 'barrel', 'stock', 'music', 'etc', 'all', 'corners', 'were', 'cut', 'except', 'the', 'one', 'that', 'would', 'have', 'prevented', 'this', 'film', 's', 'release', 'life', 's', 'like', 'that']

# %% [markdown]
# ### Build the Model

# %%
#Build the model
model = gensim.models.Word2Vec(documents, #Word list
                               min_count=10, #Ignore all words with total frequency lower than this                           
                               workers=4, #Number of CPUs
                               size=50,  #Embedding size
                               window=5, #Maximum Distance between current and predicted word
                               iter=10   #Number of iterations over the text corpus
                              )
# Out:
# 2018-11-03 07:35:30,882 : WARNING : consider setting layer size to a multiple of 4 for greater performance
# 2018-11-03 07:35:30,883 : INFO : collecting all words and their counts
# 2018-11-03 07:35:30,885 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2018-11-03 07:35:31,566 : INFO : PROGRESS: at sentence #10000, processed 2399440 words, keeping 51654 word types
# 2018-11-03 07:35:32,270 : INFO : PROGRESS: at sentence #20000, processed 4835846 words, keeping 69077 word types
# 2018-11-03 07:35:32,973 : INFO : PROGRESS: at sentence #30000, processed 7267977 words, keeping 81515 word types
# 2018-11-03 07:35:33,646 : INFO : PROGRESS: at sentence #40000, processed 9669772 words, keeping 91685 word types
# 2018-11-03 07:35:34,307 : INFO : collected 100479 word types from a corpus of 12084660 raw words and 50000 sentences
# 2018-11-03 07:35:34,309 : INFO : Loading a fresh vocabulary
# 2018-11-03 07:35:34,467 : INFO : effective_min_count=10 retains 28322 unique words (28% of original 100479, drops 72157)
# 2018-11-03 07:35:34,468 : INFO : effective_min_count=10 leaves 11910457 word corpus (98% of original 12084660, drops 174203)
# 2018-11-03 07:35:34,565 : INFO : deleting the raw counts dictionary of 100479 items
# 2018-11-03 07:35:34,570 : INFO : sample=0.001 downsamples 49 most-common words
# 2018-11-03 07:35:34,572 : INFO : downsampling leaves estimated 8817283 word corpus (74.0% of prior 11910457)
# 2018-11-03 07:35:34,710 : INFO : estimated required memory for 28322 words and 50 dimensions: 25489800 bytes
# 2018-11-03 07:35:34,712 : INFO : resetting layer weights
# 2018-11-03 07:35:34,978 : INFO : training model with 4 workers on 28322 vocabulary and 50 features, using sg=0 hs=0 sample=0.001 negative=5 window=5
# 2018-11-03 07:35:36,016 : INFO : EPOCH 1 - PROGRESS: at 5.67% examples, 487613 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:35:37,017 : INFO : EPOCH 1 - PROGRESS: at 11.40% examples, 491672 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:35:38,030 : INFO : EPOCH 1 - PROGRESS: at 17.34% examples, 497851 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:35:39,042 : INFO : EPOCH 1 - PROGRESS: at 23.14% examples, 498690 words/s, in_qsize 6, out_qsize 1
# 2018-11-03 07:35:40,070 : INFO : EPOCH 1 - PROGRESS: at 28.98% examples, 500748 words/s, in_qsize 7, out_qsize 1
# 2018-11-03 07:35:41,072 : INFO : EPOCH 1 - PROGRESS: at 34.75% examples, 501823 words/s, in_qsize 6, out_qsize 1
# 2018-11-03 07:35:42,079 : INFO : EPOCH 1 - PROGRESS: at 40.48% examples, 503097 words/s, in_qsize 6, out_qsize 0
# 2018-11-03 07:35:43,080 : INFO : EPOCH 1 - PROGRESS: at 46.24% examples, 504581 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:35:44,115 : INFO : EPOCH 1 - PROGRESS: at 52.17% examples, 503948 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:35:45,118 : INFO : EPOCH 1 - PROGRESS: at 57.97% examples, 505132 words/s, in_qsize 6, out_qsize 1
# 2018-11-03 07:35:46,130 : INFO : EPOCH 1 - PROGRESS: at 63.72% examples, 505602 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:35:47,134 : INFO : EPOCH 1 - PROGRESS: at 69.37% examples, 504554 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:35:48,139 : INFO : EPOCH 1 - PROGRESS: at 75.43% examples, 506308 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:35:49,153 : INFO : EPOCH 1 - PROGRESS: at 81.35% examples, 506481 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:35:50,187 : INFO : EPOCH 1 - PROGRESS: at 87.28% examples, 506069 words/s, in_qsize 6, out_qsize 1
# 2018-11-03 07:35:51,193 : INFO : EPOCH 1 - PROGRESS: at 93.16% examples, 506896 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:35:52,199 : INFO : EPOCH 1 - PROGRESS: at 99.08% examples, 507558 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:35:52,314 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-11-03 07:35:52,330 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-11-03 07:35:52,334 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-11-03 07:35:52,347 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-11-03 07:35:52,348 : INFO : EPOCH - 1 : training on 12084660 raw words (8817049 effective words) took 17.4s, 507880 effective words/s
# 2018-11-03 07:35:53,388 : INFO : EPOCH 2 - PROGRESS: at 5.82% examples, 500118 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:35:54,400 : INFO : EPOCH 2 - PROGRESS: at 11.73% examples, 502777 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:35:55,402 : INFO : EPOCH 2 - PROGRESS: at 17.74% examples, 509208 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:35:56,404 : INFO : EPOCH 2 - PROGRESS: at 23.53% examples, 508408 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:35:57,420 : INFO : EPOCH 2 - PROGRESS: at 29.31% examples, 508273 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:35:58,442 : INFO : EPOCH 2 - PROGRESS: at 35.13% examples, 507564 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:35:59,460 : INFO : EPOCH 2 - PROGRESS: at 40.94% examples, 508356 words/s, in_qsize 6, out_qsize 1
# 2018-11-03 07:36:00,469 : INFO : EPOCH 2 - PROGRESS: at 46.70% examples, 508647 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:36:01,472 : INFO : EPOCH 2 - PROGRESS: at 52.64% examples, 509411 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:36:02,505 : INFO : EPOCH 2 - PROGRESS: at 58.44% examples, 508606 words/s, in_qsize 8, out_qsize 2
# 2018-11-03 07:36:03,527 : INFO : EPOCH 2 - PROGRESS: at 64.37% examples, 509654 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:36:04,534 : INFO : EPOCH 2 - PROGRESS: at 70.30% examples, 509890 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:36:05,553 : INFO : EPOCH 2 - PROGRESS: at 76.16% examples, 509553 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:36:06,559 : INFO : EPOCH 2 - PROGRESS: at 82.07% examples, 509755 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:36:07,559 : INFO : EPOCH 2 - PROGRESS: at 87.99% examples, 510234 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:36:08,565 : INFO : EPOCH 2 - PROGRESS: at 93.96% examples, 511225 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:36:09,568 : INFO : EPOCH 2 - PROGRESS: at 99.73% examples, 510911 words/s, in_qsize 4, out_qsize 0
# 2018-11-03 07:36:09,595 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-11-03 07:36:09,596 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-11-03 07:36:09,599 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-11-03 07:36:09,605 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-11-03 07:36:09,606 : INFO : EPOCH - 2 : training on 12084660 raw words (8817547 effective words) took 17.2s, 511172 effective words/s
# 2018-11-03 07:36:10,620 : INFO : EPOCH 3 - PROGRESS: at 5.52% examples, 482993 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:36:11,622 : INFO : EPOCH 3 - PROGRESS: at 11.48% examples, 499972 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:36:12,630 : INFO : EPOCH 3 - PROGRESS: at 17.17% examples, 497306 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:36:13,637 : INFO : EPOCH 3 - PROGRESS: at 23.07% examples, 500544 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:36:14,669 : INFO : EPOCH 3 - PROGRESS: at 28.89% examples, 501832 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:36:15,678 : INFO : EPOCH 3 - PROGRESS: at 34.74% examples, 503453 words/s, in_qsize 6, out_qsize 1
# 2018-11-03 07:36:16,688 : INFO : EPOCH 3 - PROGRESS: at 40.55% examples, 505269 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:36:17,689 : INFO : EPOCH 3 - PROGRESS: at 46.16% examples, 504693 words/s, in_qsize 5, out_qsize 2
# 2018-11-03 07:36:18,710 : INFO : EPOCH 3 - PROGRESS: at 52.17% examples, 505642 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:36:19,710 : INFO : EPOCH 3 - PROGRESS: at 57.64% examples, 504024 words/s, in_qsize 8, out_qsize 1
# 2018-11-03 07:36:20,734 : INFO : EPOCH 3 - PROGRESS: at 63.47% examples, 504633 words/s, in_qsize 8, out_qsize 0
# 2018-11-03 07:36:21,758 : INFO : EPOCH 3 - PROGRESS: at 69.45% examples, 505191 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:36:22,771 : INFO : EPOCH 3 - PROGRESS: at 75.33% examples, 505477 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:36:23,786 : INFO : EPOCH 3 - PROGRESS: at 81.27% examples, 505665 words/s, in_qsize 7, out_qsize 1
# 2018-11-03 07:36:24,802 : INFO : EPOCH 3 - PROGRESS: at 87.37% examples, 506870 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:36:25,804 : INFO : EPOCH 3 - PROGRESS: at 93.09% examples, 506890 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:36:26,808 : INFO : EPOCH 3 - PROGRESS: at 98.84% examples, 506771 words/s, in_qsize 6, out_qsize 1
# 2018-11-03 07:36:26,951 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-11-03 07:36:26,971 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-11-03 07:36:26,977 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-11-03 07:36:26,987 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-11-03 07:36:26,988 : INFO : EPOCH - 3 : training on 12084660 raw words (8817000 effective words) took 17.4s, 507425 effective words/s
# 2018-11-03 07:36:28,021 : INFO : EPOCH 4 - PROGRESS: at 5.74% examples, 496197 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:36:29,030 : INFO : EPOCH 4 - PROGRESS: at 11.81% examples, 508465 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:36:30,031 : INFO : EPOCH 4 - PROGRESS: at 17.81% examples, 513116 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:36:31,052 : INFO : EPOCH 4 - PROGRESS: at 23.60% examples, 509101 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:36:32,059 : INFO : EPOCH 4 - PROGRESS: at 29.48% examples, 511222 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:36:33,070 : INFO : EPOCH 4 - PROGRESS: at 35.32% examples, 510974 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:36:34,087 : INFO : EPOCH 4 - PROGRESS: at 41.04% examples, 510423 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:36:35,090 : INFO : EPOCH 4 - PROGRESS: at 46.86% examples, 511699 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:36:36,108 : INFO : EPOCH 4 - PROGRESS: at 52.81% examples, 511330 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:36:37,141 : INFO : EPOCH 4 - PROGRESS: at 58.52% examples, 509580 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:36:38,180 : INFO : EPOCH 4 - PROGRESS: at 64.37% examples, 509080 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:36:39,183 : INFO : EPOCH 4 - PROGRESS: at 70.31% examples, 509504 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:36:40,199 : INFO : EPOCH 4 - PROGRESS: at 76.24% examples, 509947 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:36:41,205 : INFO : EPOCH 4 - PROGRESS: at 82.15% examples, 510099 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:36:42,211 : INFO : EPOCH 4 - PROGRESS: at 88.07% examples, 510361 words/s, in_qsize 6, out_qsize 1
# 2018-11-03 07:36:43,227 : INFO : EPOCH 4 - PROGRESS: at 94.04% examples, 511213 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:36:44,215 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-11-03 07:36:44,222 : INFO : EPOCH 4 - PROGRESS: at 99.90% examples, 511371 words/s, in_qsize 1, out_qsize 3
# 2018-11-03 07:36:44,224 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-11-03 07:36:44,226 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-11-03 07:36:44,228 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-11-03 07:36:44,229 : INFO : EPOCH - 4 : training on 12084660 raw words (8818219 effective words) took 17.2s, 511720 effective words/s
# 2018-11-03 07:36:45,248 : INFO : EPOCH 5 - PROGRESS: at 5.67% examples, 499791 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:36:46,258 : INFO : EPOCH 5 - PROGRESS: at 11.50% examples, 499636 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:36:47,261 : INFO : EPOCH 5 - PROGRESS: at 17.34% examples, 502451 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:36:48,281 : INFO : EPOCH 5 - PROGRESS: at 23.22% examples, 502924 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:36:49,299 : INFO : EPOCH 5 - PROGRESS: at 28.98% examples, 503657 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:36:50,299 : INFO : EPOCH 5 - PROGRESS: at 34.75% examples, 504413 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:36:51,307 : INFO : EPOCH 5 - PROGRESS: at 40.46% examples, 505326 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:36:52,310 : INFO : EPOCH 5 - PROGRESS: at 46.08% examples, 504618 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:36:53,322 : INFO : EPOCH 5 - PROGRESS: at 52.17% examples, 506862 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:36:54,323 : INFO : EPOCH 5 - PROGRESS: at 57.82% examples, 506477 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:36:55,332 : INFO : EPOCH 5 - PROGRESS: at 63.56% examples, 506905 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:36:56,340 : INFO : EPOCH 5 - PROGRESS: at 69.54% examples, 507940 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:36:57,342 : INFO : EPOCH 5 - PROGRESS: at 75.43% examples, 508429 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:36:58,350 : INFO : EPOCH 5 - PROGRESS: at 81.35% examples, 508631 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:36:59,357 : INFO : EPOCH 5 - PROGRESS: at 87.19% examples, 508509 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:37:00,361 : INFO : EPOCH 5 - PROGRESS: at 93.01% examples, 508848 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:37:01,362 : INFO : EPOCH 5 - PROGRESS: at 98.84% examples, 509092 words/s, in_qsize 8, out_qsize 0
# 2018-11-03 07:37:01,514 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-11-03 07:37:01,523 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-11-03 07:37:01,535 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-11-03 07:37:01,536 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-11-03 07:37:01,539 : INFO : EPOCH - 5 : training on 12084660 raw words (8817090 effective words) took 17.3s, 509817 effective words/s
# 2018-11-03 07:37:02,566 : INFO : EPOCH 6 - PROGRESS: at 5.67% examples, 491384 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:37:03,587 : INFO : EPOCH 6 - PROGRESS: at 11.57% examples, 496280 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:37:04,626 : INFO : EPOCH 6 - PROGRESS: at 17.49% examples, 496671 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:37:05,641 : INFO : EPOCH 6 - PROGRESS: at 23.38% examples, 499081 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:37:06,652 : INFO : EPOCH 6 - PROGRESS: at 29.08% examples, 499958 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:37:07,655 : INFO : EPOCH 6 - PROGRESS: at 34.82% examples, 501074 words/s, in_qsize 8, out_qsize 0
# 2018-11-03 07:37:08,662 : INFO : EPOCH 6 - PROGRESS: at 40.48% examples, 501442 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:37:09,664 : INFO : EPOCH 6 - PROGRESS: at 46.24% examples, 503135 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:37:10,688 : INFO : EPOCH 6 - PROGRESS: at 52.01% examples, 501690 words/s, in_qsize 6, out_qsize 1
# 2018-11-03 07:37:11,709 : INFO : EPOCH 6 - PROGRESS: at 57.82% examples, 502277 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:37:12,722 : INFO : EPOCH 6 - PROGRESS: at 63.56% examples, 502930 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:37:13,723 : INFO : EPOCH 6 - PROGRESS: at 69.28% examples, 502781 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:37:14,746 : INFO : EPOCH 6 - PROGRESS: at 75.24% examples, 503425 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:37:15,750 : INFO : EPOCH 6 - PROGRESS: at 81.18% examples, 504128 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:37:16,752 : INFO : EPOCH 6 - PROGRESS: at 87.01% examples, 504466 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:37:17,767 : INFO : EPOCH 6 - PROGRESS: at 92.76% examples, 504274 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:37:18,811 : INFO : EPOCH 6 - PROGRESS: at 98.84% examples, 504768 words/s, in_qsize 8, out_qsize 2
# 2018-11-03 07:37:18,956 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-11-03 07:37:18,968 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-11-03 07:37:18,978 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-11-03 07:37:18,987 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-11-03 07:37:18,988 : INFO : EPOCH - 6 : training on 12084660 raw words (8817110 effective words) took 17.4s, 505538 effective words/s
# 2018-11-03 07:37:20,005 : INFO : EPOCH 7 - PROGRESS: at 5.75% examples, 503091 words/s, in_qsize 6, out_qsize 1
# 2018-11-03 07:37:21,012 : INFO : EPOCH 7 - PROGRESS: at 11.57% examples, 501819 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:37:22,038 : INFO : EPOCH 7 - PROGRESS: at 17.49% examples, 502539 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:37:23,065 : INFO : EPOCH 7 - PROGRESS: at 23.45% examples, 503827 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:37:24,089 : INFO : EPOCH 7 - PROGRESS: at 29.40% examples, 506642 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:37:25,120 : INFO : EPOCH 7 - PROGRESS: at 35.32% examples, 506740 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:37:26,137 : INFO : EPOCH 7 - PROGRESS: at 41.04% examples, 506658 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:37:27,163 : INFO : EPOCH 7 - PROGRESS: at 46.78% examples, 506142 words/s, in_qsize 5, out_qsize 2
# 2018-11-03 07:37:28,164 : INFO : EPOCH 7 - PROGRESS: at 52.65% examples, 506496 words/s, in_qsize 6, out_qsize 1
# 2018-11-03 07:37:29,168 : INFO : EPOCH 7 - PROGRESS: at 58.44% examples, 507396 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:37:30,179 : INFO : EPOCH 7 - PROGRESS: at 64.29% examples, 508360 words/s, in_qsize 8, out_qsize 0
# 2018-11-03 07:37:31,188 : INFO : EPOCH 7 - PROGRESS: at 69.94% examples, 506863 words/s, in_qsize 6, out_qsize 1
# 2018-11-03 07:37:32,214 : INFO : EPOCH 7 - PROGRESS: at 75.92% examples, 507334 words/s, in_qsize 7, out_qsize 1
# 2018-11-03 07:37:33,246 : INFO : EPOCH 7 - PROGRESS: at 81.99% examples, 507536 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:37:34,262 : INFO : EPOCH 7 - PROGRESS: at 87.91% examples, 507641 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:37:35,277 : INFO : EPOCH 7 - PROGRESS: at 93.80% examples, 508071 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:37:36,298 : INFO : EPOCH 7 - PROGRESS: at 99.65% examples, 507852 words/s, in_qsize 3, out_qsize 3
# 2018-11-03 07:37:36,306 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-11-03 07:37:36,310 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-11-03 07:37:36,322 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-11-03 07:37:36,327 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-11-03 07:37:36,329 : INFO : EPOCH - 7 : training on 12084660 raw words (8817950 effective words) took 17.3s, 508716 effective words/s
# 2018-11-03 07:37:37,340 : INFO : EPOCH 8 - PROGRESS: at 5.45% examples, 476668 words/s, in_qsize 6, out_qsize 1
# 2018-11-03 07:37:38,346 : INFO : EPOCH 8 - PROGRESS: at 11.41% examples, 495643 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:37:39,365 : INFO : EPOCH 8 - PROGRESS: at 17.26% examples, 497305 words/s, in_qsize 6, out_qsize 1
# 2018-11-03 07:37:40,387 : INFO : EPOCH 8 - PROGRESS: at 23.21% examples, 500219 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:37:41,406 : INFO : EPOCH 8 - PROGRESS: at 29.08% examples, 503046 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:37:42,412 : INFO : EPOCH 8 - PROGRESS: at 34.82% examples, 503471 words/s, in_qsize 6, out_qsize 1
# 2018-11-03 07:37:43,416 : INFO : EPOCH 8 - PROGRESS: at 40.55% examples, 504760 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:37:44,430 : INFO : EPOCH 8 - PROGRESS: at 46.31% examples, 505206 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:37:45,432 : INFO : EPOCH 8 - PROGRESS: at 52.17% examples, 505523 words/s, in_qsize 6, out_qsize 1
# 2018-11-03 07:37:46,443 : INFO : EPOCH 8 - PROGRESS: at 57.97% examples, 506241 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:37:47,456 : INFO : EPOCH 8 - PROGRESS: at 63.64% examples, 505879 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:37:48,457 : INFO : EPOCH 8 - PROGRESS: at 69.69% examples, 507881 words/s, in_qsize 8, out_qsize 0
# 2018-11-03 07:37:49,507 : INFO : EPOCH 8 - PROGRESS: at 75.67% examples, 507098 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:37:50,518 : INFO : EPOCH 8 - PROGRESS: at 81.68% examples, 507807 words/s, in_qsize 6, out_qsize 1
# 2018-11-03 07:37:51,533 : INFO : EPOCH 8 - PROGRESS: at 87.76% examples, 508870 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:37:52,535 : INFO : EPOCH 8 - PROGRESS: at 93.60% examples, 509240 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:37:53,573 : INFO : EPOCH 8 - PROGRESS: at 99.57% examples, 509211 words/s, in_qsize 6, out_qsize 0
# 2018-11-03 07:37:53,590 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-11-03 07:37:53,609 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-11-03 07:37:53,619 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-11-03 07:37:53,628 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-11-03 07:37:53,630 : INFO : EPOCH - 8 : training on 12084660 raw words (8816645 effective words) took 17.3s, 509746 effective words/s
# 2018-11-03 07:37:54,656 : INFO : EPOCH 9 - PROGRESS: at 5.75% examples, 496966 words/s, in_qsize 8, out_qsize 0
# 2018-11-03 07:37:55,664 : INFO : EPOCH 9 - PROGRESS: at 11.55% examples, 498672 words/s, in_qsize 6, out_qsize 1
# 2018-11-03 07:37:56,687 : INFO : EPOCH 9 - PROGRESS: at 17.58% examples, 503156 words/s, in_qsize 6, out_qsize 1
# 2018-11-03 07:37:57,691 : INFO : EPOCH 9 - PROGRESS: at 23.46% examples, 505413 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:37:58,693 : INFO : EPOCH 9 - PROGRESS: at 29.31% examples, 508707 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:37:59,706 : INFO : EPOCH 9 - PROGRESS: at 35.06% examples, 507498 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:38:00,743 : INFO : EPOCH 9 - PROGRESS: at 40.94% examples, 507986 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:38:01,758 : INFO : EPOCH 9 - PROGRESS: at 46.71% examples, 507995 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:38:02,766 : INFO : EPOCH 9 - PROGRESS: at 52.65% examples, 508529 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:38:03,771 : INFO : EPOCH 9 - PROGRESS: at 58.27% examples, 507853 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:38:04,772 : INFO : EPOCH 9 - PROGRESS: at 64.04% examples, 508531 words/s, in_qsize 6, out_qsize 1
# 2018-11-03 07:38:05,788 : INFO : EPOCH 9 - PROGRESS: at 69.85% examples, 507866 words/s, in_qsize 6, out_qsize 1
# 2018-11-03 07:38:06,807 : INFO : EPOCH 9 - PROGRESS: at 75.84% examples, 508277 words/s, in_qsize 7, out_qsize 1
# 2018-11-03 07:38:07,815 : INFO : EPOCH 9 - PROGRESS: at 81.76% examples, 508475 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:38:08,837 : INFO : EPOCH 9 - PROGRESS: at 87.68% examples, 508268 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:38:09,858 : INFO : EPOCH 9 - PROGRESS: at 93.60% examples, 508497 words/s, in_qsize 6, out_qsize 1
# 2018-11-03 07:38:10,859 : INFO : EPOCH 9 - PROGRESS: at 99.57% examples, 509618 words/s, in_qsize 6, out_qsize 0
# 2018-11-03 07:38:10,921 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-11-03 07:38:10,923 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-11-03 07:38:10,937 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-11-03 07:38:10,939 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-11-03 07:38:10,940 : INFO : EPOCH - 9 : training on 12084660 raw words (8816108 effective words) took 17.3s, 509432 effective words/s
# 2018-11-03 07:38:11,950 : INFO : EPOCH 10 - PROGRESS: at 5.52% examples, 484318 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:38:12,980 : INFO : EPOCH 10 - PROGRESS: at 11.57% examples, 497648 words/s, in_qsize 6, out_qsize 1
# 2018-11-03 07:38:13,993 : INFO : EPOCH 10 - PROGRESS: at 17.42% examples, 500356 words/s, in_qsize 8, out_qsize 3
# 2018-11-03 07:38:15,012 : INFO : EPOCH 10 - PROGRESS: at 23.38% examples, 502349 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:38:16,017 : INFO : EPOCH 10 - PROGRESS: at 29.08% examples, 503059 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:38:17,036 : INFO : EPOCH 10 - PROGRESS: at 34.84% examples, 502408 words/s, in_qsize 6, out_qsize 1
# 2018-11-03 07:38:18,040 : INFO : EPOCH 10 - PROGRESS: at 40.55% examples, 503842 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:38:19,045 : INFO : EPOCH 10 - PROGRESS: at 46.24% examples, 504063 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:38:20,048 : INFO : EPOCH 10 - PROGRESS: at 52.09% examples, 504483 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:38:21,051 : INFO : EPOCH 10 - PROGRESS: at 57.82% examples, 504929 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:38:22,070 : INFO : EPOCH 10 - PROGRESS: at 63.38% examples, 503829 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:38:23,087 : INFO : EPOCH 10 - PROGRESS: at 69.26% examples, 504114 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:38:24,095 : INFO : EPOCH 10 - PROGRESS: at 75.15% examples, 504693 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:38:25,114 : INFO : EPOCH 10 - PROGRESS: at 81.18% examples, 505285 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:38:26,147 : INFO : EPOCH 10 - PROGRESS: at 87.28% examples, 505899 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:38:27,151 : INFO : EPOCH 10 - PROGRESS: at 93.01% examples, 505977 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:38:28,175 : INFO : EPOCH 10 - PROGRESS: at 98.84% examples, 505750 words/s, in_qsize 7, out_qsize 0
# 2018-11-03 07:38:28,333 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-11-03 07:38:28,341 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-11-03 07:38:28,349 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-11-03 07:38:28,361 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-11-03 07:38:28,362 : INFO : EPOCH - 10 : training on 12084660 raw words (8817106 effective words) took 17.4s, 506213 effective words/s
# 2018-11-03 07:38:28,363 : INFO : training on a 120846600 raw words (88171824 effective words) took 173.4s, 508538 effective words/s

# %% [markdown]
# # Exploring the model

# %% [markdown]
# ### How many words in the model

# %%
#Model size
model.wv.syn0.shape
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `syn0` (Attribute will be removed in 4.0.0, use self.wv.vectors instead).
#   """Entry point for launching an IPython kernel.
# (28322, 50)

# %%
# Vocablury of the model
model.wv.vocab
# Out:
# {'watching': <gensim.models.keyedvectors.Vocab at 0x7f0243f89c18>,
#  'time': <gensim.models.keyedvectors.Vocab at 0x7f0243a82ac8>,
#  'chasers': <gensim.models.keyedvectors.Vocab at 0x7f0243a82a58>,
#  'it': <gensim.models.keyedvectors.Vocab at 0x7f0243a82a20>,
#  'obvious': <gensim.models.keyedvectors.Vocab at 0x7f0243a82a90>,
#  'that': <gensim.models.keyedvectors.Vocab at 0x7f021c2b51d0>,
#  'was': <gensim.models.keyedvectors.Vocab at 0x7f021c2b5160>,
#  'made': <gensim.models.keyedvectors.Vocab at 0x7f021c2b50b8>,
#  'by': <gensim.models.keyedvectors.Vocab at 0x7f021c2b5128>,
#  'a': <gensim.models.keyedvectors.Vocab at 0x7f021c2b5240>,
#  'bunch': <gensim.models.keyedvectors.Vocab at 0x7f021c2b52e8>,
#  'of': <gensim.models.keyedvectors.Vocab at 0x7f021c2b52b0>,
#  'friends': <gensim.models.keyedvectors.Vocab at 0x7f021c2b5320>,
#  'maybe': <gensim.models.keyedvectors.Vocab at 0x7f021c2b5358>,
#  'they': <gensim.models.keyedvectors.Vocab at 0x7f021c2b5390>,
#  'were': <gensim.models.keyedvectors.Vocab at 0x7f021c2b53c8>,
#  'sitting': <gensim.models.keyedvectors.Vocab at 0x7f021c2b5400>,
#  'around': <gensim.models.keyedvectors.Vocab at 0x7f021c2b5438>,
#  'one': <gensim.models.keyedvectors.Vocab at 0x7f021c2b5470>,
#  'day': <gensim.models.keyedvectors.Vocab at 0x7f021c2b54a8>,
#  'in': <gensim.models.keyedvectors.Vocab at 0x7f021c2b54e0>,
#  'film': <gensim.models.keyedvectors.Vocab at 0x7f021c2b5518>,
#  'school': <gensim.models.keyedvectors.Vocab at 0x7f021c2b5550>,
#  'and': <gensim.models.keyedvectors.Vocab at 0x7f021c2b5588>,
#  'said': <gensim.models.keyedvectors.Vocab at 0x7f021c2b55c0>,
#  'hey': <gensim.models.keyedvectors.Vocab at 0x7f021c2b55f8>,
#  'let': <gensim.models.keyedvectors.Vocab at 0x7f021c2b5630>,
#  's': <gensim.models.keyedvectors.Vocab at 0x7f021c2b5668>,
#  'pool': <gensim.models.keyedvectors.Vocab at 0x7f021c2b56a0>,
#  'our': <gensim.models.keyedvectors.Vocab at 0x7f021c2b56d8>,
#  'money': <gensim.models.keyedvectors.Vocab at 0x7f021c2b5710>,
#  'together': <gensim.models.keyedvectors.Vocab at 0x7f021c2b5748>,
#  'make': <gensim.models.keyedvectors.Vocab at 0x7f021c2b5780>,
#  'really': <gensim.models.keyedvectors.Vocab at 0x7f021c2b57b8>,
#  'bad': <gensim.models.keyedvectors.Vocab at 0x7f021c2b57f0>,
#  'movie': <gensim.models.keyedvectors.Vocab at 0x7f021c2b5828>,
#  'or': <gensim.models.keyedvectors.Vocab at 0x7f021c2b5860>,
#  'something': <gensim.models.keyedvectors.Vocab at 0x7f021c2b5898>,
#  'like': <gensim.models.keyedvectors.Vocab at 0x7f021c2b58d0>,
#  'what': <gensim.models.keyedvectors.Vocab at 0x7f021c2b5908>,
#  'ever': <gensim.models.keyedvectors.Vocab at 0x7f021c2b5940>,
#  'still': <gensim.models.keyedvectors.Vocab at 0x7f021c2b5978>,
#  'ended': <gensim.models.keyedvectors.Vocab at 0x7f021c2b59b0>,
#  'up': <gensim.models.keyedvectors.Vocab at 0x7f021c2b59e8>,
#  'making': <gensim.models.keyedvectors.Vocab at 0x7f021c2b5a20>,
#  'dull': <gensim.models.keyedvectors.Vocab at 0x7f021c2b5a58>,
#  'story': <gensim.models.keyedvectors.Vocab at 0x7f021c2b5a90>,
#  'script': <gensim.models.keyedvectors.Vocab at 0x7f021c2b5ac8>,
#  'lame': <gensim.models.keyedvectors.Vocab at 0x7f021c2b5b00>,
#  'acting': <gensim.models.keyedvectors.Vocab at 0x7f021c2b5b38>,
#  'poor': <gensim.models.keyedvectors.Vocab at 0x7f021c2b5b70>,
#  'cinematography': <gensim.models.keyedvectors.Vocab at 0x7f021c2b5ba8>,
#  'bottom': <gensim.models.keyedvectors.Vocab at 0x7f021c2b5be0>,
#  'the': <gensim.models.keyedvectors.Vocab at 0x7f021c2b5c18>,
#  'barrel': <gensim.models.keyedvectors.Vocab at 0x7f021c2b5c50>,
#  'stock': <gensim.models.keyedvectors.Vocab at 0x7f021c2b5c88>,
#  'music': <gensim.models.keyedvectors.Vocab at 0x7f021c2b5cc0>,
#  'etc': <gensim.models.keyedvectors.Vocab at 0x7f021c2b5cf8>,
#  'all': <gensim.models.keyedvectors.Vocab at 0x7f021c2b5d30>,
#  'corners': <gensim.models.keyedvectors.Vocab at 0x7f021c2b5d68>,
#  'cut': <gensim.models.keyedvectors.Vocab at 0x7f021c2b5da0>,
#  'except': <gensim.models.keyedvectors.Vocab at 0x7f021c2b5dd8>,
#  'would': <gensim.models.keyedvectors.Vocab at 0x7f021c2b5e10>,
#  'have': <gensim.models.keyedvectors.Vocab at 0x7f021c2b5e48>,
#  'prevented': <gensim.models.keyedvectors.Vocab at 0x7f021c2b5e80>,
#  'this': <gensim.models.keyedvectors.Vocab at 0x7f021c2b5eb8>,
#  'release': <gensim.models.keyedvectors.Vocab at 0x7f021c2b5ef0>,
#  'life': <gensim.models.keyedvectors.Vocab at 0x7f021c2b5f28>,
#  'i': <gensim.models.keyedvectors.Vocab at 0x7f021c2b5f60>,
#  'saw': <gensim.models.keyedvectors.Vocab at 0x7f021c2b5f98>,
#  'about': <gensim.models.keyedvectors.Vocab at 0x7f021c2b5fd0>,
#  'years': <gensim.models.keyedvectors.Vocab at 0x7f021c255048>,
#  'ago': <gensim.models.keyedvectors.Vocab at 0x7f021c255080>,
#  'remember': <gensim.models.keyedvectors.Vocab at 0x7f021c2550b8>,
#  'as': <gensim.models.keyedvectors.Vocab at 0x7f021c2550f0>,
#  'being': <gensim.models.keyedvectors.Vocab at 0x7f021c255128>,
#  'particularly': <gensim.models.keyedvectors.Vocab at 0x7f021c255160>,
#  'nasty': <gensim.models.keyedvectors.Vocab at 0x7f021c255198>,
#  'believe': <gensim.models.keyedvectors.Vocab at 0x7f021c2551d0>,
#  'is': <gensim.models.keyedvectors.Vocab at 0x7f021c255208>,
#  'based': <gensim.models.keyedvectors.Vocab at 0x7f021c255240>,
#  'on': <gensim.models.keyedvectors.Vocab at 0x7f021c255278>,
#  'true': <gensim.models.keyedvectors.Vocab at 0x7f021c2552b0>,
#  'incident': <gensim.models.keyedvectors.Vocab at 0x7f021c2552e8>,
#  'young': <gensim.models.keyedvectors.Vocab at 0x7f021c255320>,
#  'man': <gensim.models.keyedvectors.Vocab at 0x7f021c255358>,
#  'breaks': <gensim.models.keyedvectors.Vocab at 0x7f021c255390>,
#  'into': <gensim.models.keyedvectors.Vocab at 0x7f021c2553c8>,
#  'nurses': <gensim.models.keyedvectors.Vocab at 0x7f021c255400>,
#  'home': <gensim.models.keyedvectors.Vocab at 0x7f021c255438>,
#  'rapes': <gensim.models.keyedvectors.Vocab at 0x7f021c255470>,
#  'tortures': <gensim.models.keyedvectors.Vocab at 0x7f021c2554a8>,
#  'kills': <gensim.models.keyedvectors.Vocab at 0x7f021c2554e0>,
#  'various': <gensim.models.keyedvectors.Vocab at 0x7f021c255518>,
#  'women': <gensim.models.keyedvectors.Vocab at 0x7f021c255550>,
#  'br': <gensim.models.keyedvectors.Vocab at 0x7f021c255588>,
#  'black': <gensim.models.keyedvectors.Vocab at 0x7f021c2555c0>,
#  'white': <gensim.models.keyedvectors.Vocab at 0x7f021c2555f8>,
#  'but': <gensim.models.keyedvectors.Vocab at 0x7f021c255630>,
#  'saves': <gensim.models.keyedvectors.Vocab at 0x7f021c255668>,
#  'colour': <gensim.models.keyedvectors.Vocab at 0x7f021c2556a0>,
#  'for': <gensim.models.keyedvectors.Vocab at 0x7f021c2556d8>,
#  'shocking': <gensim.models.keyedvectors.Vocab at 0x7f021c255710>,
#  'shot': <gensim.models.keyedvectors.Vocab at 0x7f021c255748>,
#  'at': <gensim.models.keyedvectors.Vocab at 0x7f021c255780>,
#  'end': <gensim.models.keyedvectors.Vocab at 0x7f021c2557b8>,
#  'seems': <gensim.models.keyedvectors.Vocab at 0x7f021c2557f0>,
#  'to': <gensim.models.keyedvectors.Vocab at 0x7f021c255828>,
#  'be': <gensim.models.keyedvectors.Vocab at 0x7f021c255860>,
#  'trying': <gensim.models.keyedvectors.Vocab at 0x7f021c255898>,
#  'some': <gensim.models.keyedvectors.Vocab at 0x7f021c2558d0>,
#  'political': <gensim.models.keyedvectors.Vocab at 0x7f021c255908>,
#  'statement': <gensim.models.keyedvectors.Vocab at 0x7f021c255940>,
#  'just': <gensim.models.keyedvectors.Vocab at 0x7f021c255978>,
#  'comes': <gensim.models.keyedvectors.Vocab at 0x7f021c2559b0>,
#  'across': <gensim.models.keyedvectors.Vocab at 0x7f021c2559e8>,
#  'confused': <gensim.models.keyedvectors.Vocab at 0x7f021c255a20>,
#  'obscene': <gensim.models.keyedvectors.Vocab at 0x7f021c255a58>,
#  'avoid': <gensim.models.keyedvectors.Vocab at 0x7f021c255a90>,
#  'minor': <gensim.models.keyedvectors.Vocab at 0x7f021c255ac8>,
#  'spoilers': <gensim.models.keyedvectors.Vocab at 0x7f021c255b00>,
#  'new': <gensim.models.keyedvectors.Vocab at 0x7f021c255b38>,
#  'york': <gensim.models.keyedvectors.Vocab at 0x7f021c255b70>,
#  'joan': <gensim.models.keyedvectors.Vocab at 0x7f021c255ba8>,
#  'barnard': <gensim.models.keyedvectors.Vocab at 0x7f021c255be0>,
#  'elvire': <gensim.models.keyedvectors.Vocab at 0x7f021c255c18>,
#  'audrey': <gensim.models.keyedvectors.Vocab at 0x7f021c255c50>,
#  'informed': <gensim.models.keyedvectors.Vocab at 0x7f021c255c88>,
#  'her': <gensim.models.keyedvectors.Vocab at 0x7f021c255cc0>,
#  'husband': <gensim.models.keyedvectors.Vocab at 0x7f021c255cf8>,
#  'arthur': <gensim.models.keyedvectors.Vocab at 0x7f021c255d30>,
#  'john': <gensim.models.keyedvectors.Vocab at 0x7f021c255d68>,
#  'saxon': <gensim.models.keyedvectors.Vocab at 0x7f021c255da0>,
#  'mysteriously': <gensim.models.keyedvectors.Vocab at 0x7f021c255dd8>,
#  'murdered': <gensim.models.keyedvectors.Vocab at 0x7f021c255e10>,
#  'italy': <gensim.models.keyedvectors.Vocab at 0x7f021c255e48>,
#  'while': <gensim.models.keyedvectors.Vocab at 0x7f021c255e80>,
#  'searching': <gensim.models.keyedvectors.Vocab at 0x7f021c255eb8>,
#  'an': <gensim.models.keyedvectors.Vocab at 0x7f021c255ef0>,
#  'etruscan': <gensim.models.keyedvectors.Vocab at 0x7f021c255f28>,
#  'tomb': <gensim.models.keyedvectors.Vocab at 0x7f021c255f60>,
#  'decides': <gensim.models.keyedvectors.Vocab at 0x7f021c255f98>,
#  'travel': <gensim.models.keyedvectors.Vocab at 0x7f021c255fd0>,
#  'company': <gensim.models.keyedvectors.Vocab at 0x7f021c258048>,
#  'colleague': <gensim.models.keyedvectors.Vocab at 0x7f021c258080>,
#  'who': <gensim.models.keyedvectors.Vocab at 0x7f021c2580b8>,
#  'offers': <gensim.models.keyedvectors.Vocab at 0x7f021c2580f0>,
#  'his': <gensim.models.keyedvectors.Vocab at 0x7f021c258128>,
#  'support': <gensim.models.keyedvectors.Vocab at 0x7f021c258160>,
#  'once': <gensim.models.keyedvectors.Vocab at 0x7f021c258198>,
#  'she': <gensim.models.keyedvectors.Vocab at 0x7f021c2581d0>,
#  'starts': <gensim.models.keyedvectors.Vocab at 0x7f021c258208>,
#  'having': <gensim.models.keyedvectors.Vocab at 0x7f021c258240>,
#  'visions': <gensim.models.keyedvectors.Vocab at 0x7f021c258278>,
#  'relative': <gensim.models.keyedvectors.Vocab at 0x7f021c2582b0>,
#  'ancient': <gensim.models.keyedvectors.Vocab at 0x7f021c2582e8>,
#  'people': <gensim.models.keyedvectors.Vocab at 0x7f021c258320>,
#  'maggots': <gensim.models.keyedvectors.Vocab at 0x7f021c258358>,
#  'many': <gensim.models.keyedvectors.Vocab at 0x7f021c258390>,
#  'after': <gensim.models.keyedvectors.Vocab at 0x7f021c2583c8>,
#  'shootings': <gensim.models.keyedvectors.Vocab at 0x7f021c258400>,
#  'weird': <gensim.models.keyedvectors.Vocab at 0x7f021c258438>,
#  'events': <gensim.models.keyedvectors.Vocab at 0x7f021c258470>,
#  'realizes': <gensim.models.keyedvectors.Vocab at 0x7f021c2584a8>,
#  'father': <gensim.models.keyedvectors.Vocab at 0x7f021c2584e0>,
#  'international': <gensim.models.keyedvectors.Vocab at 0x7f021c258518>,
#  'drug': <gensim.models.keyedvectors.Vocab at 0x7f021c258550>,
#  'dealer': <gensim.models.keyedvectors.Vocab at 0x7f021c258588>,
#  'there': <gensim.models.keyedvectors.Vocab at 0x7f021c2585c0>,
#  'are': <gensim.models.keyedvectors.Vocab at 0x7f021c2585f8>,
#  'drugs': <gensim.models.keyedvectors.Vocab at 0x7f021c258630>,
#  'hidden': <gensim.models.keyedvectors.Vocab at 0x7f021c258668>,
#  'detective': <gensim.models.keyedvectors.Vocab at 0x7f021c2586a0>,
#  'narcotic': <gensim.models.keyedvectors.Vocab at 0x7f021c2586d8>,
#  'department': <gensim.models.keyedvectors.Vocab at 0x7f021c258710>,
#  'ends': <gensim.models.keyedvectors.Vocab at 0x7f021c258748>,
#  'back': <gensim.models.keyedvectors.Vocab at 0x7f021c258780>,
#  'when': <gensim.models.keyedvectors.Vocab at 0x7f021c2587b8>,
#  'decide': <gensim.models.keyedvectors.Vocab at 0x7f021c2587f0>,
#  'get': <gensim.models.keyedvectors.Vocab at 0x7f021c258828>,
#  'married': <gensim.models.keyedvectors.Vocab at 0x7f021c258860>,
#  'with': <gensim.models.keyedvectors.Vocab at 0x7f021c258898>,
#  'each': <gensim.models.keyedvectors.Vocab at 0x7f021c2588d0>,
#  'other': <gensim.models.keyedvectors.Vocab at 0x7f021c258908>,
#  'very': <gensim.models.keyedvectors.Vocab at 0x7f021c258940>,
#  'romantic': <gensim.models.keyedvectors.Vocab at 0x7f021c258978>,
#  'yesterday': <gensim.models.keyedvectors.Vocab at 0x7f021c2589b0>,
#  'had': <gensim.models.keyedvectors.Vocab at 0x7f021c2589e8>,
#  'displeasure': <gensim.models.keyedvectors.Vocab at 0x7f021c258a20>,
#  'wasting': <gensim.models.keyedvectors.Vocab at 0x7f021c258a58>,
#  'my': <gensim.models.keyedvectors.Vocab at 0x7f021c258a90>,
#  'crap': <gensim.models.keyedvectors.Vocab at 0x7f021c258ac8>,
#  'so': <gensim.models.keyedvectors.Vocab at 0x7f021c258b00>,
#  'absurd': <gensim.models.keyedvectors.Vocab at 0x7f021c258b38>,
#  'mixing': <gensim.models.keyedvectors.Vocab at 0x7f021c258b70>,
#  'thriller': <gensim.models.keyedvectors.Vocab at 0x7f021c258ba8>,
#  'crime': <gensim.models.keyedvectors.Vocab at 0x7f021c258be0>,
#  'supernatural': <gensim.models.keyedvectors.Vocab at 0x7f021c258c18>,
#  'horror': <gensim.models.keyedvectors.Vocab at 0x7f021c258c50>,
#  'even': <gensim.models.keyedvectors.Vocab at 0x7f021c258c88>,
#  'non': <gensim.models.keyedvectors.Vocab at 0x7f021c258cc0>,
#  'sense': <gensim.models.keyedvectors.Vocab at 0x7f021c258cf8>,
#  'way': <gensim.models.keyedvectors.Vocab at 0x7f021c258d30>,
#  'worst': <gensim.models.keyedvectors.Vocab at 0x7f021c258d68>,
#  'possible': <gensim.models.keyedvectors.Vocab at 0x7f021c258da0>,
#  'highlighting': <gensim.models.keyedvectors.Vocab at 0x7f021c258dd8>,
#  'horrible': <gensim.models.keyedvectors.Vocab at 0x7f021c258e10>,
#  'performance': <gensim.models.keyedvectors.Vocab at 0x7f021c258e48>,
#  'beautiful': <gensim.models.keyedvectors.Vocab at 0x7f021c258e80>,
#  'gives': <gensim.models.keyedvectors.Vocab at 0x7f021c258eb8>,
#  'name': <gensim.models.keyedvectors.Vocab at 0x7f021c258ef0>,
#  'credits': <gensim.models.keyedvectors.Vocab at 0x7f021c258f28>,
#  'works': <gensim.models.keyedvectors.Vocab at 0x7f021c258f60>,
#  'less': <gensim.models.keyedvectors.Vocab at 0x7f021c258f98>,
#  'than': <gensim.models.keyedvectors.Vocab at 0x7f021c258fd0>,
#  'five': <gensim.models.keyedvectors.Vocab at 0x7f021c25a048>,
#  'minutes': <gensim.models.keyedvectors.Vocab at 0x7f021c25a080>,
#  'character': <gensim.models.keyedvectors.Vocab at 0x7f021c25a0b8>,
#  'killed': <gensim.models.keyedvectors.Vocab at 0x7f021c25a0f0>,
#  'special': <gensim.models.keyedvectors.Vocab at 0x7f021c25a128>,
#  'effects': <gensim.models.keyedvectors.Vocab at 0x7f021c25a160>,
#  'limited': <gensim.models.keyedvectors.Vocab at 0x7f021c25a198>,
#  'everywhere': <gensim.models.keyedvectors.Vocab at 0x7f021c25a1d0>,
#  'direction': <gensim.models.keyedvectors.Vocab at 0x7f021c25a208>,
#  'ridiculous': <gensim.models.keyedvectors.Vocab at 0x7f021c25a240>,
#  'lost': <gensim.models.keyedvectors.Vocab at 0x7f021c25a278>,
#  'couple': <gensim.models.keyedvectors.Vocab at 0x7f021c25a2b0>,
#  'hours': <gensim.models.keyedvectors.Vocab at 0x7f021c25a2e8>,
#  'al': <gensim.models.keyedvectors.Vocab at 0x7f021c25a320>,
#  'if': <gensim.models.keyedvectors.Vocab at 0x7f021c25a358>,
#  'you': <gensim.models.keyedvectors.Vocab at 0x7f021c25a390>,
#  'desire': <gensim.models.keyedvectors.Vocab at 0x7f021c25a3c8>,
#  'curiosity': <gensim.models.keyedvectors.Vocab at 0x7f021c25a400>,
#  'seeing': <gensim.models.keyedvectors.Vocab at 0x7f021c25a438>,
#  'trash': <gensim.models.keyedvectors.Vocab at 0x7f021c25a470>,
#  'choose': <gensim.models.keyedvectors.Vocab at 0x7f021c25a4a8>,
#  'another': <gensim.models.keyedvectors.Vocab at 0x7f021c25a4e0>,
#  'go': <gensim.models.keyedvectors.Vocab at 0x7f021c25a518>,
#  'watch': <gensim.models.keyedvectors.Vocab at 0x7f021c25a550>,
#  'tv': <gensim.models.keyedvectors.Vocab at 0x7f021c25a588>,
#  'sleep': <gensim.models.keyedvectors.Vocab at 0x7f021c25a5c0>,
#  'navigate': <gensim.models.keyedvectors.Vocab at 0x7f021c25a5f8>,
#  'internet': <gensim.models.keyedvectors.Vocab at 0x7f021c25a630>,
#  'gym': <gensim.models.keyedvectors.Vocab at 0x7f021c25a668>,
#  'do': <gensim.models.keyedvectors.Vocab at 0x7f021c25a6a0>,
#  'not': <gensim.models.keyedvectors.Vocab at 0x7f021c25a6d8>,
#  'waste': <gensim.models.keyedvectors.Vocab at 0x7f021c25a710>,
#  'your': <gensim.models.keyedvectors.Vocab at 0x7f021c25a748>,
#  'did': <gensim.models.keyedvectors.Vocab at 0x7f021c25a780>,
#  'vote': <gensim.models.keyedvectors.Vocab at 0x7f021c25a7b8>,
#  'two': <gensim.models.keyedvectors.Vocab at 0x7f021c25a7f0>,
#  'title': <gensim.models.keyedvectors.Vocab at 0x7f021c25a828>,
#  'brazil': <gensim.models.keyedvectors.Vocab at 0x7f021c25a860>,
#  'o': <gensim.models.keyedvectors.Vocab at 0x7f021c25a898>,
#  'mist': <gensim.models.keyedvectors.Vocab at 0x7f021c25a8d0>,
#  'rio': <gensim.models.keyedvectors.Vocab at 0x7f021c25a908>,
#  'mystery': <gensim.models.keyedvectors.Vocab at 0x7f021c25a940>,
#  'went': <gensim.models.keyedvectors.Vocab at 0x7f021c25a978>,
#  'see': <gensim.models.keyedvectors.Vocab at 0x7f021c25a9b0>,
#  'great': <gensim.models.keyedvectors.Vocab at 0x7f021c25a9e8>,
#  'deal': <gensim.models.keyedvectors.Vocab at 0x7f021c25aa20>,
#  'excitement': <gensim.models.keyedvectors.Vocab at 0x7f021c25aa58>,
#  'director': <gensim.models.keyedvectors.Vocab at 0x7f021c25aa90>,
#  'he': <gensim.models.keyedvectors.Vocab at 0x7f021c25aac8>,
#  'good': <gensim.models.keyedvectors.Vocab at 0x7f021c25ab00>,
#  'friend': <gensim.models.keyedvectors.Vocab at 0x7f021c25ab38>,
#  'mine': <gensim.models.keyedvectors.Vocab at 0x7f021c25ab70>,
#  'sorry': <gensim.models.keyedvectors.Vocab at 0x7f021c25aba8>,
#  'mate': <gensim.models.keyedvectors.Vocab at 0x7f021c25abe0>,
#  'stinks': <gensim.models.keyedvectors.Vocab at 0x7f021c25ac18>,
#  'can': <gensim.models.keyedvectors.Vocab at 0x7f021c25ac50>,
#  'only': <gensim.models.keyedvectors.Vocab at 0x7f021c25ac88>,
#  'talk': <gensim.models.keyedvectors.Vocab at 0x7f021c25acc0>,
#  'wrong': <gensim.models.keyedvectors.Vocab at 0x7f021c25acf8>,
#  'first': <gensim.models.keyedvectors.Vocab at 0x7f021c25ad30>,
#  'half': <gensim.models.keyedvectors.Vocab at 0x7f021c25ad68>,
#  'because': <gensim.models.keyedvectors.Vocab at 0x7f021c25ada0>,
#  'walked': <gensim.models.keyedvectors.Vocab at 0x7f021c25add8>,
#  'out': <gensim.models.keyedvectors.Vocab at 0x7f021c25ae10>,
#  'pub': <gensim.models.keyedvectors.Vocab at 0x7f021c25ae48>,
#  'much': <gensim.models.keyedvectors.Vocab at 0x7f021c25ae80>,
#  'needed': <gensim.models.keyedvectors.Vocab at 0x7f021c25aeb8>,
#  'drink': <gensim.models.keyedvectors.Vocab at 0x7f021c25aef0>,
#  'someone': <gensim.models.keyedvectors.Vocab at 0x7f021c25af28>,
#  'standing': <gensim.models.keyedvectors.Vocab at 0x7f021c25af60>,
#  'balcony': <gensim.models.keyedvectors.Vocab at 0x7f021c25af98>,
#  'jump': <gensim.models.keyedvectors.Vocab at 0x7f021c25afd0>,
#  'send': <gensim.models.keyedvectors.Vocab at 0x7f021c25e048>,
#  'helicopter': <gensim.models.keyedvectors.Vocab at 0x7f021c25e080>,
#  'shine': <gensim.models.keyedvectors.Vocab at 0x7f021c25e0b8>,
#  'them': <gensim.models.keyedvectors.Vocab at 0x7f021c25e0f0>,
#  'don': <gensim.models.keyedvectors.Vocab at 0x7f021c25e128>,
#  't': <gensim.models.keyedvectors.Vocab at 0x7f021c25e160>,
#  'think': <gensim.models.keyedvectors.Vocab at 0x7f021c25e198>,
#  'nothing': <gensim.models.keyedvectors.Vocab at 0x7f021c25e1d0>,
#  'more': <gensim.models.keyedvectors.Vocab at 0x7f021c25e208>,
#  'likely': <gensim.models.keyedvectors.Vocab at 0x7f021c25e240>,
#  'local': <gensim.models.keyedvectors.Vocab at 0x7f021c25e278>,
#  'radio': <gensim.models.keyedvectors.Vocab at 0x7f021c25e2b0>,
#  'doesn': <gensim.models.keyedvectors.Vocab at 0x7f021c25e2e8>,
#  'reporters': <gensim.models.keyedvectors.Vocab at 0x7f021c25e320>,
#  'cover': <gensim.models.keyedvectors.Vocab at 0x7f021c25e358>,
#  'attempt': <gensim.models.keyedvectors.Vocab at 0x7f021c25e390>,
#  'suicide': <gensim.models.keyedvectors.Vocab at 0x7f021c25e3c8>,
#  'again': <gensim.models.keyedvectors.Vocab at 0x7f021c25e400>,
#  'fear': <gensim.models.keyedvectors.Vocab at 0x7f021c25e438>,
#  'jumping': <gensim.models.keyedvectors.Vocab at 0x7f021c25e470>,
#  'encouraging': <gensim.models.keyedvectors.Vocab at 0x7f021c25e4a8>,
#  'copy': <gensim.models.keyedvectors.Vocab at 0x7f021c25e4e0>,
#  'cat': <gensim.models.keyedvectors.Vocab at 0x7f021c25e518>,
#  'instances': <gensim.models.keyedvectors.Vocab at 0x7f021c25e550>,
#  'whatever': <gensim.models.keyedvectors.Vocab at 0x7f021c25e588>,
#  'circumstances': <gensim.models.keyedvectors.Vocab at 0x7f021c25e5c0>,
#  'live': <gensim.models.keyedvectors.Vocab at 0x7f021c25e5f8>,
#  'broadcasts': <gensim.models.keyedvectors.Vocab at 0x7f021c25e630>,
#  'from': <gensim.models.keyedvectors.Vocab at 0x7f021c25e668>,
#  'th': <gensim.models.keyedvectors.Vocab at 0x7f021c25e6a0>,
#  'floor': <gensim.models.keyedvectors.Vocab at 0x7f021c25e6d8>,
#  'tower': <gensim.models.keyedvectors.Vocab at 0x7f021c25e710>,
#  'block': <gensim.models.keyedvectors.Vocab at 0x7f021c25e748>,
#  'cars': <gensim.models.keyedvectors.Vocab at 0x7f021c25e780>,
#  'carry': <gensim.models.keyedvectors.Vocab at 0x7f021c25e7b8>,
#  'leads': <gensim.models.keyedvectors.Vocab at 0x7f021c25e7f0>,
#  'long': <gensim.models.keyedvectors.Vocab at 0x7f021c25e828>,
#  'enough': <gensim.models.keyedvectors.Vocab at 0x7f021c25e860>,
#  'connect': <gensim.models.keyedvectors.Vocab at 0x7f021c25e898>,
#  'microphone': <gensim.models.keyedvectors.Vocab at 0x7f021c25e8d0>,
#  'headphones': <gensim.models.keyedvectors.Vocab at 0x7f021c25e908>,
#  'transmitter': <gensim.models.keyedvectors.Vocab at 0x7f021c25e940>,
#  'stuck': <gensim.models.keyedvectors.Vocab at 0x7f021c25e978>,
#  'lift': <gensim.models.keyedvectors.Vocab at 0x7f021c25e9b0>,
#  'scene': <gensim.models.keyedvectors.Vocab at 0x7f021c25e9e8>,
#  'utterly': <gensim.models.keyedvectors.Vocab at 0x7f021c25ea20>,
#  'derivative': <gensim.models.keyedvectors.Vocab at 0x7f021c25ea58>,
#  'almost': <gensim.models.keyedvectors.Vocab at 0x7f021c25ea90>,
#  'existent': <gensim.models.keyedvectors.Vocab at 0x7f021c25eac8>,
#  'could': <gensim.models.keyedvectors.Vocab at 0x7f021c25eb00>,
#  'won': <gensim.models.keyedvectors.Vocab at 0x7f021c25eb38>,
#  'yes': <gensim.models.keyedvectors.Vocab at 0x7f021c25eb70>,
#  'agree': <gensim.models.keyedvectors.Vocab at 0x7f021c25eba8>,
#  'everyone': <gensim.models.keyedvectors.Vocab at 0x7f021c25ebe0>,
#  'site': <gensim.models.keyedvectors.Vocab at 0x7f021c25ec18>,
#  'call': <gensim.models.keyedvectors.Vocab at 0x7f021c25ec50>,
#  'insult': <gensim.models.keyedvectors.Vocab at 0x7f021c25ec88>,
#  'movies': <gensim.models.keyedvectors.Vocab at 0x7f021c25ecc0>,
#  'compares': <gensim.models.keyedvectors.Vocab at 0x7f021c25ecf8>,
#  'b': <gensim.models.keyedvectors.Vocab at 0x7f021c25ed30>,
#  'n': <gensim.models.keyedvectors.Vocab at 0x7f021c25ed68>,
#  'g': <gensim.models.keyedvectors.Vocab at 0x7f021c25eda0>,
#  'describes': <gensim.models.keyedvectors.Vocab at 0x7f021c25edd8>,
#  'perfectly': <gensim.models.keyedvectors.Vocab at 0x7f021c25ee10>,
#  'packaging': <gensim.models.keyedvectors.Vocab at 0x7f021c25ee48>,
#  'intentionally': <gensim.models.keyedvectors.Vocab at 0x7f021c25ee80>,
#  'misleading': <gensim.models.keyedvectors.Vocab at 0x7f021c25eeb8>,
#  'example': <gensim.models.keyedvectors.Vocab at 0x7f021c25eef0>,
#  'should': <gensim.models.keyedvectors.Vocab at 0x7f021c25ef28>,
#  'describe': <gensim.models.keyedvectors.Vocab at 0x7f021c25ef60>,
#  'hint': <gensim.models.keyedvectors.Vocab at 0x7f021c25ef98>,
#  'retitled': <gensim.models.keyedvectors.Vocab at 0x7f021c25efd0>,
#  'package': <gensim.models.keyedvectors.Vocab at 0x7f021c261048>,
#  'goofy': <gensim.models.keyedvectors.Vocab at 0x7f021c261080>,
#  'face': <gensim.models.keyedvectors.Vocab at 0x7f021c2610b8>,
#  'jim': <gensim.models.keyedvectors.Vocab at 0x7f021c2610f0>,
#  'probably': <gensim.models.keyedvectors.Vocab at 0x7f021c261128>,
#  'stand': <gensim.models.keyedvectors.Vocab at 0x7f021c261160>,
#  'days': <gensim.models.keyedvectors.Vocab at 0x7f021c261198>,
#  'hoping': <gensim.models.keyedvectors.Vocab at 0x7f021c2611d0>,
#  'now': <gensim.models.keyedvectors.Vocab at 0x7f021c261208>,
#  'actor': <gensim.models.keyedvectors.Vocab at 0x7f021c261240>,
#  'love': <gensim.models.keyedvectors.Vocab at 0x7f021c261278>,
#  'him': <gensim.models.keyedvectors.Vocab at 0x7f021c2612b0>,
#  'locate': <gensim.models.keyedvectors.Vocab at 0x7f021c2612e8>,
#  'rodney': <gensim.models.keyedvectors.Vocab at 0x7f021c261320>,
#  'dangerfield': <gensim.models.keyedvectors.Vocab at 0x7f021c261358>,
#  'comedians': <gensim.models.keyedvectors.Vocab at 0x7f021c261390>,
#  'hbo': <gensim.models.keyedvectors.Vocab at 0x7f021c2613c8>,
#  'featured': <gensim.models.keyedvectors.Vocab at 0x7f021c261400>,
#  'early': <gensim.models.keyedvectors.Vocab at 0x7f021c261438>,
#  'career': <gensim.models.keyedvectors.Vocab at 0x7f021c261470>,
#  'isn': <gensim.models.keyedvectors.Vocab at 0x7f021c2614a8>,
#  'mentioned': <gensim.models.keyedvectors.Vocab at 0x7f021c2614e0>,
#  'd': <gensim.models.keyedvectors.Vocab at 0x7f021c261518>,
#  'find': <gensim.models.keyedvectors.Vocab at 0x7f021c261550>,
#  'anything': <gensim.models.keyedvectors.Vocab at 0x7f021c261588>,
#  'wise': <gensim.models.keyedvectors.Vocab at 0x7f021c2615c0>,
#  'also': <gensim.models.keyedvectors.Vocab at 0x7f021c2615f8>,
#  'carrey': <gensim.models.keyedvectors.Vocab at 0x7f021c261630>,
#  'supporting': <gensim.models.keyedvectors.Vocab at 0x7f021c261668>,
#  'main': <gensim.models.keyedvectors.Vocab at 0x7f021c2616a0>,
#  'annoying': <gensim.models.keyedvectors.Vocab at 0x7f021c2616d8>,
#  'girl': <gensim.models.keyedvectors.Vocab at 0x7f021c261710>,
#  'lacking': <gensim.models.keyedvectors.Vocab at 0x7f021c261748>,
#  'self': <gensim.models.keyedvectors.Vocab at 0x7f021c261780>,
#  'confidence': <gensim.models.keyedvectors.Vocab at 0x7f021c2617b8>,
#  'yet': <gensim.models.keyedvectors.Vocab at 0x7f021c2617f0>,
#  'wants': <gensim.models.keyedvectors.Vocab at 0x7f021c261828>,
#  'comedian': <gensim.models.keyedvectors.Vocab at 0x7f021c261860>,
#  'say': <gensim.models.keyedvectors.Vocab at 0x7f021c261898>,
#  'lines': <gensim.models.keyedvectors.Vocab at 0x7f021c2618d0>,
#  'funny': <gensim.models.keyedvectors.Vocab at 0x7f021c261908>,
#  'janet': <gensim.models.keyedvectors.Vocab at 0x7f021c261940>,
#  'talented': <gensim.models.keyedvectors.Vocab at 0x7f021c261978>,
#  'honestly': <gensim.models.keyedvectors.Vocab at 0x7f021c2619b0>,
#  'terrible': <gensim.models.keyedvectors.Vocab at 0x7f021c2619e8>,
#  'beware': <gensim.models.keyedvectors.Vocab at 0x7f021c261a20>,
#  'false': <gensim.models.keyedvectors.Vocab at 0x7f021c261a58>,
#  'advertising': <gensim.models.keyedvectors.Vocab at 0x7f021c261a90>,
#  'jennifer': <gensim.models.keyedvectors.Vocab at 0x7f021c261ac8>,
#  'ehle': <gensim.models.keyedvectors.Vocab at 0x7f021c261b00>,
#  'sparkling': <gensim.models.keyedvectors.Vocab at 0x7f021c261b38>,
#  'pride': <gensim.models.keyedvectors.Vocab at 0x7f021c261b70>,
#  'prejudice': <gensim.models.keyedvectors.Vocab at 0x7f021c261ba8>,
#  'jeremy': <gensim.models.keyedvectors.Vocab at 0x7f021c261be0>,
#  'northam': <gensim.models.keyedvectors.Vocab at 0x7f021c261c18>,
#  'simply': <gensim.models.keyedvectors.Vocab at 0x7f021c261c50>,
#  'wonderful': <gensim.models.keyedvectors.Vocab at 0x7f021c261c88>,
#  'boy': <gensim.models.keyedvectors.Vocab at 0x7f021c261cc0>,
#  'actors': <gensim.models.keyedvectors.Vocab at 0x7f021c261cf8>,
#  'caliber': <gensim.models.keyedvectors.Vocab at 0x7f021c261d30>,
#  'lot': <gensim.models.keyedvectors.Vocab at 0x7f021c261d68>,
#  'going': <gensim.models.keyedvectors.Vocab at 0x7f021c261da0>,
#  'those': <gensim.models.keyedvectors.Vocab at 0x7f021c261dd8>,
#  'critical': <gensim.models.keyedvectors.Vocab at 0x7f021c261e10>,
#  'spoke': <gensim.models.keyedvectors.Vocab at 0x7f021c261e48>,
#  'sequences': <gensim.models.keyedvectors.Vocab at 0x7f021c261e80>,
#  'involving': <gensim.models.keyedvectors.Vocab at 0x7f021c261eb8>,
#  'these': <gensim.models.keyedvectors.Vocab at 0x7f021c261ef0>,
#  'eager': <gensim.models.keyedvectors.Vocab at 0x7f021c261f28>,
#  'bitter': <gensim.models.keyedvectors.Vocab at 0x7f021c261f60>,
#  'disappointment': <gensim.models.keyedvectors.Vocab at 0x7f021c261f98>,
#  'however': <gensim.models.keyedvectors.Vocab at 0x7f021c261fd0>,
#  'must': <gensim.models.keyedvectors.Vocab at 0x7f021c264048>,
#  'report': <gensim.models.keyedvectors.Vocab at 0x7f021c264080>,
#  'flick': <gensim.models.keyedvectors.Vocab at 0x7f021c2640b8>,
#  'piece': <gensim.models.keyedvectors.Vocab at 0x7f021c2640f0>,
#  'scenes': <gensim.models.keyedvectors.Vocab at 0x7f021c264128>,
#  'between': <gensim.models.keyedvectors.Vocab at 0x7f021c264160>,
#  'no': <gensim.models.keyedvectors.Vocab at 0x7f021c264198>,
#  'depth': <gensim.models.keyedvectors.Vocab at 0x7f021c2641d0>,
#  'tenderness': <gensim.models.keyedvectors.Vocab at 0x7f021c264208>,
#  'real': <gensim.models.keyedvectors.Vocab at 0x7f021c264240>,
#  'passion': <gensim.models.keyedvectors.Vocab at 0x7f021c264278>,
#  'consisted': <gensim.models.keyedvectors.Vocab at 0x7f021c2642b0>,
#  'hackneyed': <gensim.models.keyedvectors.Vocab at 0x7f021c2642e8>,
#  'unsubtle': <gensim.models.keyedvectors.Vocab at 0x7f021c264320>,
#  'latter': <gensim.models.keyedvectors.Vocab at 0x7f021c264358>,
#  'cinematic': <gensim.models.keyedvectors.Vocab at 0x7f021c264390>,
#  'lust': <gensim.models.keyedvectors.Vocab at 0x7f021c2643c8>,
#  'voracious': <gensim.models.keyedvectors.Vocab at 0x7f021c264400>,
#  'open': <gensim.models.keyedvectors.Vocab at 0x7f021c264438>,
#  'mouthed': <gensim.models.keyedvectors.Vocab at 0x7f021c264470>,
#  'kissing': <gensim.models.keyedvectors.Vocab at 0x7f021c2644a8>,
#  'soft': <gensim.models.keyedvectors.Vocab at 0x7f021c2644e0>,
#  'porn': <gensim.models.keyedvectors.Vocab at 0x7f021c264518>,
#  'humping': <gensim.models.keyedvectors.Vocab at 0x7f021c264550>,
#  'entertaining': <gensim.models.keyedvectors.Vocab at 0x7f021c264588>,
#  'done': <gensim.models.keyedvectors.Vocab at 0x7f021c2645c0>,
#  'originality': <gensim.models.keyedvectors.Vocab at 0x7f021c2645f8>,
#  'tasteless': <gensim.models.keyedvectors.Vocab at 0x7f021c264630>,
#  'awful': <gensim.models.keyedvectors.Vocab at 0x7f021c264668>,
#  'their': <gensim.models.keyedvectors.Vocab at 0x7f021c2646a0>,
#  'craft': <gensim.models.keyedvectors.Vocab at 0x7f021c2646d8>,
#  'ashamed': <gensim.models.keyedvectors.Vocab at 0x7f021c264710>,
#  'modern': <gensim.models.keyedvectors.Vocab at 0x7f021c264748>,
#  'part': <gensim.models.keyedvectors.Vocab at 0x7f021c264780>,
#  'romance': <gensim.models.keyedvectors.Vocab at 0x7f021c2647b8>,
#  'effeminate': <gensim.models.keyedvectors.Vocab at 0x7f021c2647f0>,
#  'appearance': <gensim.models.keyedvectors.Vocab at 0x7f021c264828>,
#  'male': <gensim.models.keyedvectors.Vocab at 0x7f021c264860>,
#  'lead': <gensim.models.keyedvectors.Vocab at 0x7f021c264898>,
#  'aren': <gensim.models.keyedvectors.Vocab at 0x7f021c2648d0>,
#  'any': <gensim.models.keyedvectors.Vocab at 0x7f021c264908>,
#  'masculine': <gensim.models.keyedvectors.Vocab at 0x7f021c264940>,
#  'men': <gensim.models.keyedvectors.Vocab at 0x7f021c264978>,
#  'left': <gensim.models.keyedvectors.Vocab at 0x7f021c2649b0>,
#  'hollywood': <gensim.models.keyedvectors.Vocab at 0x7f021c2649e8>,
#  'plot': <gensim.models.keyedvectors.Vocab at 0x7f021c264a20>,
#  'kind': <gensim.models.keyedvectors.Vocab at 0x7f021c264a58>,
#  'interesting': <gensim.models.keyedvectors.Vocab at 0x7f021c264a90>,
#  'better': <gensim.models.keyedvectors.Vocab at 0x7f021c264ac8>,
#  'imaginative': <gensim.models.keyedvectors.Vocab at 0x7f021c264b00>,
#  'might': <gensim.models.keyedvectors.Vocab at 0x7f021c264b38>,
#  'worked': <gensim.models.keyedvectors.Vocab at 0x7f021c264b70>,
#  'amy': <gensim.models.keyedvectors.Vocab at 0x7f021c264ba8>,
#  'terrific': <gensim.models.keyedvectors.Vocab at 0x7f021c264be0>,
#  'saturday': <gensim.models.keyedvectors.Vocab at 0x7f021c264c18>,
#  'night': <gensim.models.keyedvectors.Vocab at 0x7f021c264c50>,
#  'role': <gensim.models.keyedvectors.Vocab at 0x7f021c264c88>,
#  'give': <gensim.models.keyedvectors.Vocab at 0x7f021c264cc0>,
#  'work': <gensim.models.keyedvectors.Vocab at 0x7f021c264cf8>,
#  'publisher': <gensim.models.keyedvectors.Vocab at 0x7f021c264d30>,
#  'representative': <gensim.models.keyedvectors.Vocab at 0x7f021c264d68>,
#  'guiding': <gensim.models.keyedvectors.Vocab at 0x7f021c264da0>,
#  'author': <gensim.models.keyedvectors.Vocab at 0x7f021c264dd8>,
#  'book': <gensim.models.keyedvectors.Vocab at 0x7f021c264e10>,
#  'tour': <gensim.models.keyedvectors.Vocab at 0x7f021c264e48>,
#  'mean': <gensim.models.keyedvectors.Vocab at 0x7f021c264e80>,
#  'susan': <gensim.models.keyedvectors.Vocab at 0x7f021c264eb8>,
#  'sarandon': <gensim.models.keyedvectors.Vocab at 0x7f021c264ef0>,
#  'plays': <gensim.models.keyedvectors.Vocab at 0x7f021c264f28>,
#  'mother': <gensim.models.keyedvectors.Vocab at 0x7f021c264f60>,
#  'involved': <gensim.models.keyedvectors.Vocab at 0x7f021c264f98>,
#  'sadistic': <gensim.models.keyedvectors.Vocab at 0x7f021c264fd0>,
#  'teacher': <gensim.models.keyedvectors.Vocab at 0x7f021c269048>,
#  'billy': <gensim.models.keyedvectors.Vocab at 0x7f021c269080>,
#  'bob': <gensim.models.keyedvectors.Vocab at 0x7f021c2690b8>,
#  'thorton': <gensim.models.keyedvectors.Vocab at 0x7f021c2690f0>,
#  'chubby': <gensim.models.keyedvectors.Vocab at 0x7f021c269128>,
#  'junior': <gensim.models.keyedvectors.Vocab at 0x7f021c269160>,
#  'high': <gensim.models.keyedvectors.Vocab at 0x7f021c269198>,
#  'student': <gensim.models.keyedvectors.Vocab at 0x7f021c2691d0>,
#  'unfortunately': <gensim.models.keyedvectors.Vocab at 0x7f021c269208>,
#  'require': <gensim.models.keyedvectors.Vocab at 0x7f021c269240>,
#  'actress': <gensim.models.keyedvectors.Vocab at 0x7f021c269278>,
#  'funniest': <gensim.models.keyedvectors.Vocab at 0x7f021c2692b0>,
#  'thing': <gensim.models.keyedvectors.Vocab at 0x7f021c2692e8>,
#  'looks': <gensim.models.keyedvectors.Vocab at 0x7f021c269320>,
#  'gown': <gensim.models.keyedvectors.Vocab at 0x7f021c269358>,
#  'wears': <gensim.models.keyedvectors.Vocab at 0x7f021c269390>,
#  'queen': <gensim.models.keyedvectors.Vocab at 0x7f021c2693c8>,
#  'corn': <gensim.models.keyedvectors.Vocab at 0x7f021c269400>,
#  'festival': <gensim.models.keyedvectors.Vocab at 0x7f021c269438>,
#  'explanation': <gensim.models.keyedvectors.Vocab at 0x7f021c269470>,
#  'why': <gensim.models.keyedvectors.Vocab at 0x7f021c2694a8>,
#  'old': <gensim.models.keyedvectors.Vocab at 0x7f021c2694e0>,
#  'grown': <gensim.models.keyedvectors.Vocab at 0x7f021c269518>,
#  'son': <gensim.models.keyedvectors.Vocab at 0x7f021c269550>,
#  'stale': <gensim.models.keyedvectors.Vocab at 0x7f021c269588>,
#  'wrote': <gensim.models.keyedvectors.Vocab at 0x7f021c2695c0>,
#  'best': <gensim.models.keyedvectors.Vocab at 0x7f021c2695f8>,
#  'selling': <gensim.models.keyedvectors.Vocab at 0x7f021c269630>,
#  'help': <gensim.models.keyedvectors.Vocab at 0x7f021c269668>,
#  'then': <gensim.models.keyedvectors.Vocab at 0x7f021c2696a0>,
#  'adopts': <gensim.models.keyedvectors.Vocab at 0x7f021c2696d8>,
#  'behavior': <gensim.models.keyedvectors.Vocab at 0x7f021c269710>,
#  'contradicts': <gensim.models.keyedvectors.Vocab at 0x7f021c269748>,
#  'advice': <gensim.models.keyedvectors.Vocab at 0x7f021c269780>,
#  've': <gensim.models.keyedvectors.Vocab at 0x7f021c2697b8>,
#  'seen': <gensim.models.keyedvectors.Vocab at 0x7f021c2697f0>,
#  'didn': <gensim.models.keyedvectors.Vocab at 0x7f021c269828>,
#  'erase': <gensim.models.keyedvectors.Vocab at 0x7f021c269860>,
#  'before': <gensim.models.keyedvectors.Vocab at 0x7f021c269898>,
#  'plane': <gensim.models.keyedvectors.Vocab at 0x7f021c2698d0>,
#  'carrying': <gensim.models.keyedvectors.Vocab at 0x7f021c269908>,
#  'employees': <gensim.models.keyedvectors.Vocab at 0x7f021c269940>,
#  'large': <gensim.models.keyedvectors.Vocab at 0x7f021c269978>,
#  'firm': <gensim.models.keyedvectors.Vocab at 0x7f021c2699b0>,
#  'including': <gensim.models.keyedvectors.Vocab at 0x7f021c2699e8>,
#  'ceo': <gensim.models.keyedvectors.Vocab at 0x7f021c269a20>,
#  'daughter': <gensim.models.keyedvectors.Vocab at 0x7f021c269a58>,
#  'goes': <gensim.models.keyedvectors.Vocab at 0x7f021c269a90>,
#  'down': <gensim.models.keyedvectors.Vocab at 0x7f021c269ac8>,
#  'thick': <gensim.models.keyedvectors.Vocab at 0x7f021c269b00>,
#  'forest': <gensim.models.keyedvectors.Vocab at 0x7f021c269b38>,
#  'pacific': <gensim.models.keyedvectors.Vocab at 0x7f021c269b70>,
#  'northwest': <gensim.models.keyedvectors.Vocab at 0x7f021c269ba8>,
#  'search': <gensim.models.keyedvectors.Vocab at 0x7f021c269be0>,
#  'rescue': <gensim.models.keyedvectors.Vocab at 0x7f021c269c18>,
#  'mission': <gensim.models.keyedvectors.Vocab at 0x7f021c269c50>,
#  'called': <gensim.models.keyedvectors.Vocab at 0x7f021c269c88>,
#  'off': <gensim.models.keyedvectors.Vocab at 0x7f021c269cc0>,
#  'harlan': <gensim.models.keyedvectors.Vocab at 0x7f021c269cf8>,
#  'knowles': <gensim.models.keyedvectors.Vocab at 0x7f021c269d30>,
#  'lance': <gensim.models.keyedvectors.Vocab at 0x7f021c269d68>,
#  'henriksen': <gensim.models.keyedvectors.Vocab at 0x7f021c269da0>,
#  'puts': <gensim.models.keyedvectors.Vocab at 0x7f021c269dd8>,
#  'small': <gensim.models.keyedvectors.Vocab at 0x7f021c269e10>,
#  'ragtag': <gensim.models.keyedvectors.Vocab at 0x7f021c269e48>,
#  'group': <gensim.models.keyedvectors.Vocab at 0x7f021c269e80>,
#  'execute': <gensim.models.keyedvectors.Vocab at 0x7f021c269eb8>,
#  'own': <gensim.models.keyedvectors.Vocab at 0x7f021c269ef0>,
#  'following': <gensim.models.keyedvectors.Vocab at 0x7f021c269f28>,
#  'woods': <gensim.models.keyedvectors.Vocab at 0x7f021c269f60>,
#  'oy': <gensim.models.keyedvectors.Vocab at 0x7f021c269f98>,
#  'mess': <gensim.models.keyedvectors.Vocab at 0x7f021c269fd0>,
#  'shame': <gensim.models.keyedvectors.Vocab at 0x7f021c26c048>,
#  'stars': <gensim.models.keyedvectors.Vocab at 0x7f021c26c080>,
#  'favorite': <gensim.models.keyedvectors.Vocab at 0x7f021c26c0b8>,
#  'genre': <gensim.models.keyedvectors.Vocab at 0x7f021c26c0f0>,
#  'easily': <gensim.models.keyedvectors.Vocab at 0x7f021c26c128>,
#  'been': <gensim.models.keyedvectors.Vocab at 0x7f021c26c160>,
#  'decent': <gensim.models.keyedvectors.Vocab at 0x7f021c26c198>,
#  'suffers': <gensim.models.keyedvectors.Vocab at 0x7f021c26c1d0>,
#  'major': <gensim.models.keyedvectors.Vocab at 0x7f021c26c208>,
#  'flaws': <gensim.models.keyedvectors.Vocab at 0x7f021c26c240>,
#  're': <gensim.models.keyedvectors.Vocab at 0x7f021c26c278>,
#  'both': <gensim.models.keyedvectors.Vocab at 0x7f021c26c2b0>,
#  'writer': <gensim.models.keyedvectors.Vocab at 0x7f021c26c2e8>,
#  'jonas': <gensim.models.keyedvectors.Vocab at 0x7f021c26c320>,
#  'fault': <gensim.models.keyedvectors.Vocab at 0x7f021c26c358>,
#  'which': <gensim.models.keyedvectors.Vocab at 0x7f021c26c390>,
#  'll': <gensim.models.keyedvectors.Vocab at 0x7f021c26c3c8>,
#  'calling': <gensim.models.keyedvectors.Vocab at 0x7f021c26c400>,
#  'its': <gensim.models.keyedvectors.Vocab at 0x7f021c26c438>,
#  'aka': <gensim.models.keyedvectors.Vocab at 0x7f021c26c470>,
#  'sasquatch': <gensim.models.keyedvectors.Vocab at 0x7f021c26c4a8>,
#  'has': <gensim.models.keyedvectors.Vocab at 0x7f021c26c4e0>,
#  'editing': <gensim.models.keyedvectors.Vocab at 0x7f021c26c518>,
#  'next': <gensim.models.keyedvectors.Vocab at 0x7f021c26c550>,
#  'alone': <gensim.models.keyedvectors.Vocab at 0x7f021c26c588>,
#  'dark': <gensim.models.keyedvectors.Vocab at 0x7f021c26c5c0>,
#  'constant': <gensim.models.keyedvectors.Vocab at 0x7f021c26c5f8>,
#  'cast': <gensim.models.keyedvectors.Vocab at 0x7f021c26c630>,
#  'appears': <gensim.models.keyedvectors.Vocab at 0x7f021c26c668>,
#  'okay': <gensim.models.keyedvectors.Vocab at 0x7f021c26c6a0>,
#  'try': <gensim.models.keyedvectors.Vocab at 0x7f021c26c6d8>,
#  'want': <gensim.models.keyedvectors.Vocab at 0x7f021c26c710>,
#  'top': <gensim.models.keyedvectors.Vocab at 0x7f021c26c748>,
#  'improvise': <gensim.models.keyedvectors.Vocab at 0x7f021c26c780>,
#  'sequiturs': <gensim.models.keyedvectors.Vocab at 0x7f021c26c7b8>,
#  'generally': <gensim.models.keyedvectors.Vocab at 0x7f021c26c7f0>,
#  'potential': <gensim.models.keyedvectors.Vocab at 0x7f021c26c828>,
#  'despite': <gensim.models.keyedvectors.Vocab at 0x7f021c26c860>,
#  'rip': <gensim.models.keyedvectors.Vocab at 0x7f021c26c898>,
#  'aspects': <gensim.models.keyedvectors.Vocab at 0x7f021c26c8d0>,
#  'material': <gensim.models.keyedvectors.Vocab at 0x7f021c26c908>,
#  'related': <gensim.models.keyedvectors.Vocab at 0x7f021c26c940>,
#  'crash': <gensim.models.keyedvectors.Vocab at 0x7f021c26c978>,
#  'obviously': <gensim.models.keyedvectors.Vocab at 0x7f021c26c9b0>,
#  'crib': <gensim.models.keyedvectors.Vocab at 0x7f021c26c9e8>,
#  'blair': <gensim.models.keyedvectors.Vocab at 0x7f021c26ca20>,
#  'witch': <gensim.models.keyedvectors.Vocab at 0x7f021c26ca58>,
#  'project': <gensim.models.keyedvectors.Vocab at 0x7f021c26ca90>,
#  'titular': <gensim.models.keyedvectors.Vocab at 0x7f021c26cac8>,
#  'monster': <gensim.models.keyedvectors.Vocab at 0x7f021c26cb00>,
#  'predator': <gensim.models.keyedvectors.Vocab at 0x7f021c26cb38>,
#  'ed': <gensim.models.keyedvectors.Vocab at 0x7f021c26cb70>,
#  'wood': <gensim.models.keyedvectors.Vocab at 0x7f021c26cba8>,
#  'exposition': <gensim.models.keyedvectors.Vocab at 0x7f021c26cbe0>,
#  'dialogue': <gensim.models.keyedvectors.Vocab at 0x7f021c26cc18>,
#  'promise': <gensim.models.keyedvectors.Vocab at 0x7f021c26cc50>,
#  'subtler': <gensim.models.keyedvectors.Vocab at 0x7f021c26cc88>,
#  'far': <gensim.models.keyedvectors.Vocab at 0x7f021c26ccc0>,
#  'saccharine': <gensim.models.keyedvectors.Vocab at 0x7f021c26ccf8>,
#  'subtexts': <gensim.models.keyedvectors.Vocab at 0x7f021c26cd30>,
#  'costume': <gensim.models.keyedvectors.Vocab at 0x7f021c26cd68>,
#  'we': <gensim.models.keyedvectors.Vocab at 0x7f021c26cda0>,
#  'actually': <gensim.models.keyedvectors.Vocab at 0x7f021c26cdd8>,
#  'sufficient': <gensim.models.keyedvectors.Vocab at 0x7f021c26ce10>,
#  'tastes': <gensim.models.keyedvectors.Vocab at 0x7f021c26ce48>,
#  'mixture': <gensim.models.keyedvectors.Vocab at 0x7f021c26ce80>,
#  'types': <gensim.models.keyedvectors.Vocab at 0x7f021c26ceb8>,
#  'trudging': <gensim.models.keyedvectors.Vocab at 0x7f021c26cef0>,
#  'through': <gensim.models.keyedvectors.Vocab at 0x7f021c26cf28>,
#  'fellow': <gensim.models.keyedvectors.Vocab at 0x7f021c26cf60>,
#  'chris': <gensim.models.keyedvectors.Vocab at 0x7f021c26cf98>,
#  'turned': <gensim.models.keyedvectors.Vocab at 0x7f021c26cfd0>,
#  'stereotype': <gensim.models.keyedvectors.Vocab at 0x7f021c270048>,
#  'notch': <gensim.models.keyedvectors.Vocab at 0x7f021c270080>,
#  'least': <gensim.models.keyedvectors.Vocab at 0x7f021c2700b8>,
#  'spent': <gensim.models.keyedvectors.Vocab at 0x7f021c2700f0>,
#  'exploring': <gensim.models.keyedvectors.Vocab at 0x7f021c270128>,
#  'relationships': <gensim.models.keyedvectors.Vocab at 0x7f021c270160>,
#  'lair': <gensim.models.keyedvectors.Vocab at 0x7f021c270198>,
#  'nice': <gensim.models.keyedvectors.Vocab at 0x7f021c2701d0>,
#  'production': <gensim.models.keyedvectors.Vocab at 0x7f021c270208>,
#  'design': <gensim.models.keyedvectors.Vocab at 0x7f021c270240>,
#  'specifically': <gensim.models.keyedvectors.Vocab at 0x7f021c270278>,
#  'corpse': <gensim.models.keyedvectors.Vocab at 0x7f021c2702b0>,
#  'decorations': <gensim.models.keyedvectors.Vocab at 0x7f021c2702e8>,
#  'ala': <gensim.models.keyedvectors.Vocab at 0x7f021c270320>,
#  'primitive': <gensim.models.keyedvectors.Vocab at 0x7f021c270358>,
#  'jeepers': <gensim.models.keyedvectors.Vocab at 0x7f021c270390>,
#  'creepers': <gensim.models.keyedvectors.Vocab at 0x7f021c2703c8>,
#  'edited': <gensim.models.keyedvectors.Vocab at 0x7f021c270400>,
#  'well': <gensim.models.keyedvectors.Vocab at 0x7f021c270438>,
#  'effective': <gensim.models.keyedvectors.Vocab at 0x7f021c270470>,
#  'most': <gensim.models.keyedvectors.Vocab at 0x7f021c2704a8>,
#  'frightening': <gensim.models.keyedvectors.Vocab at 0x7f021c2704e0>,
#  'number': <gensim.models.keyedvectors.Vocab at 0x7f021c270518>,
#  'missteps': <gensim.models.keyedvectors.Vocab at 0x7f021c270550>,
#  'reason': <gensim.models.keyedvectors.Vocab at 0x7f021c270588>,
#  'thinks': <gensim.models.keyedvectors.Vocab at 0x7f021c2705c0>,
#  'idea': <gensim.models.keyedvectors.Vocab at 0x7f021c2705f8>,
#  'chop': <gensim.models.keyedvectors.Vocab at 0x7f021c270630>,
#  'occur': <gensim.models.keyedvectors.Vocab at 0x7f021c270668>,
#  'within': <gensim.models.keyedvectors.Vocab at 0x7f021c2706a0>,
#  'instead': <gensim.models.keyedvectors.Vocab at 0x7f021c2706d8>,
#  'few': <gensim.models.keyedvectors.Vocab at 0x7f021c270710>,
#  'use': <gensim.models.keyedvectors.Vocab at 0x7f021c270748>,
#  'frequently': <gensim.models.keyedvectors.Vocab at 0x7f021c270780>,
#  'screens': <gensim.models.keyedvectors.Vocab at 0x7f021c2707b8>,
#  'snippets': <gensim.models.keyedvectors.Vocab at 0x7f021c2707f0>,
#  'whether': <gensim.models.keyedvectors.Vocab at 0x7f021c270828>,
#  'need': <gensim.models.keyedvectors.Vocab at 0x7f021c270860>,
#  'unspecified': <gensim.models.keyedvectors.Vocab at 0x7f021c270898>,
#  'amount': <gensim.models.keyedvectors.Vocab at 0x7f021c2708d0>,
#  'passing': <gensim.models.keyedvectors.Vocab at 0x7f021c270908>,
#  'irrelevant': <gensim.models.keyedvectors.Vocab at 0x7f021c270940>,
#  'comments': <gensim.models.keyedvectors.Vocab at 0x7f021c270978>,
#  'seem': <gensim.models.keyedvectors.Vocab at 0x7f021c2709b0>,
#  'occurring': <gensim.models.keyedvectors.Vocab at 0x7f021c2709e8>,
#  'anyway': <gensim.models.keyedvectors.Vocab at 0x7f021c270a20>,
#  'care': <gensim.models.keyedvectors.Vocab at 0x7f021c270a58>,
#  'during': <gensim.models.keyedvectors.Vocab at 0x7f021c270a90>,
#  'morning': <gensim.models.keyedvectors.Vocab at 0x7f021c270ac8>,
#  'afternoon': <gensim.models.keyedvectors.Vocab at 0x7f021c270b00>,
#  'middle': <gensim.models.keyedvectors.Vocab at 0x7f021c270b38>,
#  'cuts': <gensim.models.keyedvectors.Vocab at 0x7f021c270b70>,
#  'random': <gensim.models.keyedvectors.Vocab at 0x7f021c270ba8>,
#  'matter': <gensim.models.keyedvectors.Vocab at 0x7f021c270be0>,
#  'shown': <gensim.models.keyedvectors.Vocab at 0x7f021c270c18>,
#  'appear': <gensim.models.keyedvectors.Vocab at 0x7f021c270c50>,
#  'selected': <gensim.models.keyedvectors.Vocab at 0x7f021c270c88>,
#  'important': <gensim.models.keyedvectors.Vocab at 0x7f021c270cc0>,
#  'either': <gensim.models.keyedvectors.Vocab at 0x7f021c270cf8>,
#  'never': <gensim.models.keyedvectors.Vocab at 0x7f021c270d30>,
#  'barely': <gensim.models.keyedvectors.Vocab at 0x7f021c270d68>,
#  'too': <gensim.models.keyedvectors.Vocab at 0x7f021c270da0>,
#  'pointless': <gensim.models.keyedvectors.Vocab at 0x7f021c270dd8>,
#  'cave': <gensim.models.keyedvectors.Vocab at 0x7f021c270e10>,
#  'art': <gensim.models.keyedvectors.Vocab at 0x7f021c270e48>,
#  'needs': <gensim.models.keyedvectors.Vocab at 0x7f021c270e80>,
#  'justify': <gensim.models.keyedvectors.Vocab at 0x7f021c270eb8>,
#  'getting': <gensim.models.keyedvectors.Vocab at 0x7f021c270ef0>,
#  'intelligence': <gensim.models.keyedvectors.Vocab at 0x7f021c270f28>,
#  'humanity': <gensim.models.keyedvectors.Vocab at 0x7f021c270f60>,
#  'whole': <gensim.models.keyedvectors.Vocab at 0x7f021c270f98>,
#  'mary': <gensim.models.keyedvectors.Vocab at 0x7f021c270fd0>,
#  'mancini': <gensim.models.keyedvectors.Vocab at 0x7f021c272048>,
#  'though': <gensim.models.keyedvectors.Vocab at 0x7f021c272080>,
#  'superfluous': <gensim.models.keyedvectors.Vocab at 0x7f021c2720b8>,
#  'suddenly': <gensim.models.keyedvectors.Vocab at 0x7f021c2720f0>,
#  'extremely': <gensim.models.keyedvectors.Vocab at 0x7f021c272128>,
#  'core': <gensim.models.keyedvectors.Vocab at 0x7f021c272160>,
#  'porno': <gensim.models.keyedvectors.Vocab at 0x7f021c272198>,
#  'motif': <gensim.models.keyedvectors.Vocab at 0x7f021c2721d0>,
#  'repeated': <gensim.models.keyedvectors.Vocab at 0x7f021c272208>,
#  'characters': <gensim.models.keyedvectors.Vocab at 0x7f021c272240>,
#  'keep': <gensim.models.keyedvectors.Vocab at 0x7f021c272278>,
#  'mr': <gensim.models.keyedvectors.Vocab at 0x7f021c2722b0>,
#  'h': <gensim.models.keyedvectors.Vocab at 0x7f021c2722e8>,
#  'stereotypes': <gensim.models.keyedvectors.Vocab at 0x7f021c272320>,
#  'asian': <gensim.models.keyedvectors.Vocab at 0x7f021c272358>,
#  'insists': <gensim.models.keyedvectors.Vocab at 0x7f021c272390>,
#  'using': <gensim.models.keyedvectors.Vocab at 0x7f021c2723c8>,
#  'blurry': <gensim.models.keyedvectors.Vocab at 0x7f021c272400>,
#  'cam': <gensim.models.keyedvectors.Vocab at 0x7f021c272438>,
#  'attack': <gensim.models.keyedvectors.Vocab at 0x7f021c272470>,
#  'look': <gensim.models.keyedvectors.Vocab at 0x7f021c2724a8>,
# ...
#  'every': <gensim.models.keyedvectors.Vocab at 0x7f021c272860>,
#  'thought': <gensim.models.keyedvectors.Vocab at 0x7f021c272898>,
#  'point': <gensim.models.keyedvectors.Vocab at 0x7f021c2728d0>,
#  'until': <gensim.models.keyedvectors.Vocab at 0x7f021c272908>,
#  'move': <gensim.models.keyedvectors.Vocab at 0x7f021c272940>,
#  'score': <gensim.models.keyedvectors.Vocab at 0x7f021c272978>,
#  'gritty': <gensim.models.keyedvectors.Vocab at 0x7f021c2729b0>,
#  'science': <gensim.models.keyedvectors.Vocab at 0x7f021c2729e8>,
#  'fiction': <gensim.models.keyedvectors.Vocab at 0x7f021c272a20>,
#  'among': <gensim.models.keyedvectors.Vocab at 0x7f021c272a58>,
#  'hundreds': <gensim.models.keyedvectors.Vocab at 0x7f021c272a90>,
#  'similar': <gensim.models.keyedvectors.Vocab at 0x7f021c272ac8>,
#  'several': <gensim.models.keyedvectors.Vocab at 0x7f021c272b00>,
#  'strong': <gensim.models.keyedvectors.Vocab at 0x7f021c272b38>,
#  'points': <gensim.models.keyedvectors.Vocab at 0x7f021c272b70>,
#  'near': <gensim.models.keyedvectors.Vocab at 0x7f021c272ba8>,
#  'writing': <gensim.models.keyedvectors.Vocab at 0x7f021c272be0>,
#  'directing': <gensim.models.keyedvectors.Vocab at 0x7f021c272c18>,
#  'solid': <gensim.models.keyedvectors.Vocab at 0x7f021c272c50>,
#  'manages': <gensim.models.keyedvectors.Vocab at 0x7f021c272c88>,
#  'sci': <gensim.models.keyedvectors.Vocab at 0x7f021c272cc0>,
#  'fi': <gensim.models.keyedvectors.Vocab at 0x7f021c272cf8>,
#  'cliches': <gensim.models.keyedvectors.Vocab at 0x7f021c272d30>,
#  'does': <gensim.models.keyedvectors.Vocab at 0x7f021c272d68>,
#  'job': <gensim.models.keyedvectors.Vocab at 0x7f021c272da0>,
#  'keeping': <gensim.models.keyedvectors.Vocab at 0x7f021c272dd8>,
#  'suspense': <gensim.models.keyedvectors.Vocab at 0x7f021c272e10>,
#  'landscape': <gensim.models.keyedvectors.Vocab at 0x7f021c272e48>,
#  'will': <gensim.models.keyedvectors.Vocab at 0x7f021c272e80>,
#  'appeal': <gensim.models.keyedvectors.Vocab at 0x7f021c272eb8>,
#  'fans': <gensim.models.keyedvectors.Vocab at 0x7f021c272ef0>,
#  'looking': <gensim.models.keyedvectors.Vocab at 0x7f021c272f28>,
#  'masterpiece': <gensim.models.keyedvectors.Vocab at 0x7f021c272f60>,
#  'fashioned': <gensim.models.keyedvectors.Vocab at 0x7f021c272f98>,
#  'post': <gensim.models.keyedvectors.Vocab at 0x7f021c272fd0>,
#  'future': <gensim.models.keyedvectors.Vocab at 0x7f021c277048>,
#  'space': <gensim.models.keyedvectors.Vocab at 0x7f021c277080>,
#  'thoroughly': <gensim.models.keyedvectors.Vocab at 0x7f021c2770b8>,
#  'enjoyable': <gensim.models.keyedvectors.Vocab at 0x7f021c2770f0>,
#  'ending': <gensim.models.keyedvectors.Vocab at 0x7f021c277128>,
#  'incredibly': <gensim.models.keyedvectors.Vocab at 0x7f021c277160>,
#  'dumb': <gensim.models.keyedvectors.Vocab at 0x7f021c277198>,
#  'predictable': <gensim.models.keyedvectors.Vocab at 0x7f021c2771d0>,
#  'rich': <gensim.models.keyedvectors.Vocab at 0x7f021c277208>,
#  'teen': <gensim.models.keyedvectors.Vocab at 0x7f021c277240>,
#  'given': <gensim.models.keyedvectors.Vocab at 0x7f021c277278>,
#  'parents': <gensim.models.keyedvectors.Vocab at 0x7f021c2772b0>,
#  'gang': <gensim.models.keyedvectors.Vocab at 0x7f021c2772e8>,
#  'rob': <gensim.models.keyedvectors.Vocab at 0x7f021c277320>,
#  'gas': <gensim.models.keyedvectors.Vocab at 0x7f021c277358>,
#  'stations': <gensim.models.keyedvectors.Vocab at 0x7f021c277390>,
#  'rape': <gensim.models.keyedvectors.Vocab at 0x7f021c2773c8>,
#  'guys': <gensim.models.keyedvectors.Vocab at 0x7f021c277400>,
#  'kill': <gensim.models.keyedvectors.Vocab at 0x7f021c277438>,
#  'policeman': <gensim.models.keyedvectors.Vocab at 0x7f021c277470>,
#  'teenagers': <gensim.models.keyedvectors.Vocab at 0x7f021c2774a8>,
#  'late': <gensim.models.keyedvectors.Vocab at 0x7f021c2774e0>,
#  'cliche': <gensim.models.keyedvectors.Vocab at 0x7f021c277518>,
#  'imaginable': <gensim.models.keyedvectors.Vocab at 0x7f021c277550>,
#  'hilarious': <gensim.models.keyedvectors.Vocab at 0x7f021c277588>,
#  'surprise': <gensim.models.keyedvectors.Vocab at 0x7f021c2775c0>,
#  'written': <gensim.models.keyedvectors.Vocab at 0x7f021c2775f8>,
#  'immortal': <gensim.models.keyedvectors.Vocab at 0x7f021c277630>,
#  'jr': <gensim.models.keyedvectors.Vocab at 0x7f021c277668>,
#  'worth': <gensim.models.keyedvectors.Vocab at 0x7f021c2776a0>,
#  'laughs': <gensim.models.keyedvectors.Vocab at 0x7f021c2776d8>,
#  'shooting': <gensim.models.keyedvectors.Vocab at 0x7f021c277710>,
#  'ain': <gensim.models.keyedvectors.Vocab at 0x7f021c277748>,
#  'supposed': <gensim.models.keyedvectors.Vocab at 0x7f021c277780>,
#  'reading': <gensim.models.keyedvectors.Vocab at 0x7f021c2777b8>,
#  'am': <gensim.models.keyedvectors.Vocab at 0x7f021c2777f0>,
#  'sure': <gensim.models.keyedvectors.Vocab at 0x7f021c277828>,
#  'angry': <gensim.models.keyedvectors.Vocab at 0x7f021c277860>,
#  'sad': <gensim.models.keyedvectors.Vocab at 0x7f021c277898>,
#  'sickened': <gensim.models.keyedvectors.Vocab at 0x7f021c2778d0>,
#  'typical': <gensim.models.keyedvectors.Vocab at 0x7f021c277908>,
#  'know': <gensim.models.keyedvectors.Vocab at 0x7f021c277940>,
#  'absolutely': <gensim.models.keyedvectors.Vocab at 0x7f021c277978>,
#  'military': <gensim.models.keyedvectors.Vocab at 0x7f021c2779b0>,
#  'base': <gensim.models.keyedvectors.Vocab at 0x7f021c2779e8>,
#  'everything': <gensim.models.keyedvectors.Vocab at 0x7f021c277a20>,
#  'cnn': <gensim.models.keyedvectors.Vocab at 0x7f021c277a58>,
#  'reports': <gensim.models.keyedvectors.Vocab at 0x7f021c277a90>,
#  'abu': <gensim.models.keyedvectors.Vocab at 0x7f021c277ac8>,
#  'makes': <gensim.models.keyedvectors.Vocab at 0x7f021c277b00>,
#  'me': <gensim.models.keyedvectors.Vocab at 0x7f021c277b38>,
#  'wonder': <gensim.models.keyedvectors.Vocab at 0x7f021c277b70>,
#  'state': <gensim.models.keyedvectors.Vocab at 0x7f021c277ba8>,
#  'intellectual': <gensim.models.keyedvectors.Vocab at 0x7f021c277be0>,
#  'stimulation': <gensim.models.keyedvectors.Vocab at 0x7f021c277c18>,
#  'world': <gensim.models.keyedvectors.Vocab at 0x7f021c277c50>,
#  'type': <gensim.models.keyedvectors.Vocab at 0x7f021c277c88>,
#  'us': <gensim.models.keyedvectors.Vocab at 0x7f021c277cc0>,
#  'million': <gensim.models.keyedvectors.Vocab at 0x7f021c277cf8>,
#  'active': <gensim.models.keyedvectors.Vocab at 0x7f021c277d30>,
#  'duty': <gensim.models.keyedvectors.Vocab at 0x7f021c277d68>,
#  'guard': <gensim.models.keyedvectors.Vocab at 0x7f021c277da0>,
#  'reserves': <gensim.models.keyedvectors.Vocab at 0x7f021c277dd8>,
#  'total': <gensim.models.keyedvectors.Vocab at 0x7f021c277e10>,
#  'roughly': <gensim.models.keyedvectors.Vocab at 0x7f021c277e48>,
#  'abuses': <gensim.models.keyedvectors.Vocab at 0x7f021c277e80>,
#  'currently': <gensim.models.keyedvectors.Vocab at 0x7f021c277eb8>,
#  'single': <gensim.models.keyedvectors.Vocab at 0x7f021c277ef0>,
#  'member': <gensim.models.keyedvectors.Vocab at 0x7f021c277f28>,
#  'stepped': <gensim.models.keyedvectors.Vocab at 0x7f021c277f60>,
#  'come': <gensim.models.keyedvectors.Vocab at 0x7f021c277f98>,
#  'close': <gensim.models.keyedvectors.Vocab at 0x7f021c277fd0>,
#  'take': <gensim.models.keyedvectors.Vocab at 0x7f021c27a048>,
#  'understand': <gensim.models.keyedvectors.Vocab at 0x7f021c27a080>,
#  'sarcastic': <gensim.models.keyedvectors.Vocab at 0x7f021c27a0b8>,
#  'reality': <gensim.models.keyedvectors.Vocab at 0x7f021c27a0f0>,
#  'commentary': <gensim.models.keyedvectors.Vocab at 0x7f021c27a128>,
#  'without': <gensim.models.keyedvectors.Vocab at 0x7f021c27a160>,
#  'enemy': <gensim.models.keyedvectors.Vocab at 0x7f021c27a198>,
#  'fight': <gensim.models.keyedvectors.Vocab at 0x7f021c27a1d0>,
#  'conflicts': <gensim.models.keyedvectors.Vocab at 0x7f021c27a208>,
#  'disaster': <gensim.models.keyedvectors.Vocab at 0x7f021c27a240>,
#  'relief': <gensim.models.keyedvectors.Vocab at 0x7f021c27a278>,
#  'humanitarian': <gensim.models.keyedvectors.Vocab at 0x7f021c27a2b0>,
#  'aid': <gensim.models.keyedvectors.Vocab at 0x7f021c27a2e8>,
#  'missions': <gensim.models.keyedvectors.Vocab at 0x7f021c27a320>,
#  'hit': <gensim.models.keyedvectors.Vocab at 0x7f021c27a358>,
#  'indonesia': <gensim.models.keyedvectors.Vocab at 0x7f021c27a390>,
#  'region': <gensim.models.keyedvectors.Vocab at 0x7f021c27a3c8>,
#  'chaos': <gensim.models.keyedvectors.Vocab at 0x7f021c27a400>,
#  'situation': <gensim.models.keyedvectors.Vocab at 0x7f021c27a438>,
#  'overwhelmed': <gensim.models.keyedvectors.Vocab at 0x7f021c27a470>,
#  'governments': <gensim.models.keyedvectors.Vocab at 0x7f021c27a4a8>,
#  'leadership': <gensim.models.keyedvectors.Vocab at 0x7f021c27a4e0>,
#  'looked': <gensim.models.keyedvectors.Vocab at 0x7f021c27a518>,
#  'same': <gensim.models.keyedvectors.Vocab at 0x7f021c27a550>,
#  'mocks': <gensim.models.keyedvectors.Vocab at 0x7f021c27a588>,
#  'happen': <gensim.models.keyedvectors.Vocab at 0x7f021c27a5c0>,
#  'food': <gensim.models.keyedvectors.Vocab at 0x7f021c27a5f8>,
#  'reaching': <gensim.models.keyedvectors.Vocab at 0x7f021c27a630>,
#  'isolated': <gensim.models.keyedvectors.Vocab at 0x7f021c27a668>,
#  'villages': <gensim.models.keyedvectors.Vocab at 0x7f021c27a6a0>,
#  'built': <gensim.models.keyedvectors.Vocab at 0x7f021c27a6d8>,
#  'cargo': <gensim.models.keyedvectors.Vocab at 0x7f021c27a710>,
#  'aircraft': <gensim.models.keyedvectors.Vocab at 0x7f021c27a748>,
#  'started': <gensim.models.keyedvectors.Vocab at 0x7f021c27a780>,
#  'landing': <gensim.models.keyedvectors.Vocab at 0x7f021c27a7b8>,
#  'distribution': <gensim.models.keyedvectors.Vocab at 0x7f021c27a7f0>,
#  'system': <gensim.models.keyedvectors.Vocab at 0x7f021c27a828>,
#  'running': <gensim.models.keyedvectors.Vocab at 0x7f021c27a860>,
#  'weeks': <gensim.models.keyedvectors.Vocab at 0x7f021c27a898>,
#  'months': <gensim.models.keyedvectors.Vocab at 0x7f021c27a8d0>,
#  'unscrupulous': <gensim.models.keyedvectors.Vocab at 0x7f021c27a908>,
#  'walk': <gensim.models.keyedvectors.Vocab at 0x7f021c27a940>,
#  'occupation': <gensim.models.keyedvectors.Vocab at 0x7f021c27a978>,
#  'website': <gensim.models.keyedvectors.Vocab at 0x7f021c27a9b0>,
#  'criminal': <gensim.models.keyedvectors.Vocab at 0x7f021c27a9e8>,
#  'minds': <gensim.models.keyedvectors.Vocab at 0x7f021c27aa20>,
#  'thoughts': <gensim.models.keyedvectors.Vocab at 0x7f021c27aa58>,
#  'destruction': <gensim.models.keyedvectors.Vocab at 0x7f021c27aa90>,
#  'mayhem': <gensim.models.keyedvectors.Vocab at 0x7f021c27aac8>,
#  'absolute': <gensim.models.keyedvectors.Vocab at 0x7f021c27ab00>,
#  'disservice': <gensim.models.keyedvectors.Vocab at 0x7f021c27ab38>,
#  'things': <gensim.models.keyedvectors.Vocab at 0x7f021c27ab70>,
#  'person': <gensim.models.keyedvectors.Vocab at 0x7f021c27aba8>,
#  'members': <gensim.models.keyedvectors.Vocab at 0x7f021c27abe0>,
#  'personal': <gensim.models.keyedvectors.Vocab at 0x7f021c27ac18>,
#  'gain': <gensim.models.keyedvectors.Vocab at 0x7f021c27ac50>,
#  'wow': <gensim.models.keyedvectors.Vocab at 0x7f021c27ac88>,
#  'entry': <gensim.models.keyedvectors.Vocab at 0x7f021c27acc0>,
#  'personnel': <gensim.models.keyedvectors.Vocab at 0x7f021c27acf8>,
#  'under': <gensim.models.keyedvectors.Vocab at 0x7f021c27ad30>,
#  'hour': <gensim.models.keyedvectors.Vocab at 0x7f021c27ad68>,
#  'assuming': <gensim.models.keyedvectors.Vocab at 0x7f021c27ada0>,
#  'week': <gensim.models.keyedvectors.Vocab at 0x7f021c27add8>,
#  'course': <gensim.models.keyedvectors.Vocab at 0x7f021c27ae10>,
#  'harm': <gensim.models.keyedvectors.Vocab at 0x7f021c27ae48>,
#  'typically': <gensim.models.keyedvectors.Vocab at 0x7f021c27ae80>,
#  'pay': <gensim.models.keyedvectors.Vocab at 0x7f021c27aeb8>,
#  'minimum': <gensim.models.keyedvectors.Vocab at 0x7f021c27aef0>,
#  'wage': <gensim.models.keyedvectors.Vocab at 0x7f021c27af28>,
#  'beg': <gensim.models.keyedvectors.Vocab at 0x7f021c27af60>,
#  'please': <gensim.models.keyedvectors.Vocab at 0x7f021c27af98>,
#  'yourself': <gensim.models.keyedvectors.Vocab at 0x7f021c27afd0>,
#  'familiar': <gensim.models.keyedvectors.Vocab at 0x7f021c27d048>,
#  'nearby': <gensim.models.keyedvectors.Vocab at 0x7f021c27d080>,
#  'visitor': <gensim.models.keyedvectors.Vocab at 0x7f021c27d0b8>,
#  'pass': <gensim.models.keyedvectors.Vocab at 0x7f021c27d0f0>,
#  'meet': <gensim.models.keyedvectors.Vocab at 0x7f021c27d128>,
#  'quick': <gensim.models.keyedvectors.Vocab at 0x7f021c27d160>,
#  'surprised': <gensim.models.keyedvectors.Vocab at 0x7f021c27d198>,
#  'longer': <gensim.models.keyedvectors.Vocab at 0x7f021c27d1d0>,
#  'accepts': <gensim.models.keyedvectors.Vocab at 0x7f021c27d208>,
#  'lieu': <gensim.models.keyedvectors.Vocab at 0x7f021c27d240>,
#  'prison': <gensim.models.keyedvectors.Vocab at 0x7f021c27d278>,
#  'ged': <gensim.models.keyedvectors.Vocab at 0x7f021c27d2b0>,
#  'prefer': <gensim.models.keyedvectors.Vocab at 0x7f021c27d2e8>,
#  'ranks': <gensim.models.keyedvectors.Vocab at 0x7f021c27d320>,
#  'expected': <gensim.models.keyedvectors.Vocab at 0x7f021c27d358>,
#  'undergraduate': <gensim.models.keyedvectors.Vocab at 0x7f021c27d390>,
#  'degrees': <gensim.models.keyedvectors.Vocab at 0x7f021c27d3c8>,
#  'upper': <gensim.models.keyedvectors.Vocab at 0x7f021c27d400>,
#  'encouraged': <gensim.models.keyedvectors.Vocab at 0x7f021c27d438>,
#  'advanced': <gensim.models.keyedvectors.Vocab at 0x7f021c27d470>,
#  'hard': <gensim.models.keyedvectors.Vocab at 0x7f021c27d4a8>,
#  'elfen': <gensim.models.keyedvectors.Vocab at 0x7f021c27d4e0>,
#  'lied': <gensim.models.keyedvectors.Vocab at 0x7f021c27d518>,
#  'hasn': <gensim.models.keyedvectors.Vocab at 0x7f021c27d550>,
#  'heard': <gensim.models.keyedvectors.Vocab at 0x7f021c27d588>,
#  'closest': <gensim.models.keyedvectors.Vocab at 0x7f021c27d5c0>,
#  'strange': <gensim.models.keyedvectors.Vocab at 0x7f021c27d5f8>,
#  'mix': <gensim.models.keyedvectors.Vocab at 0x7f021c27d630>,
#  'extreme': <gensim.models.keyedvectors.Vocab at 0x7f021c27d668>,
#  'violence': <gensim.models.keyedvectors.Vocab at 0x7f021c27d6a0>,
#  'drama': <gensim.models.keyedvectors.Vocab at 0x7f021c27d6d8>,
#  'haven': <gensim.models.keyedvectors.Vocab at 0x7f021c27d710>,
#  'witnessed': <gensim.models.keyedvectors.Vocab at 0x7f021c27d748>,
#  'wondering': <gensim.models.keyedvectors.Vocab at 0x7f021c27d780>,
#  'how': <gensim.models.keyedvectors.Vocab at 0x7f021c27d7b8>,
#  'incorporated': <gensim.models.keyedvectors.Vocab at 0x7f021c27d7f0>,
#  'coherently': <gensim.models.keyedvectors.Vocab at 0x7f021c27d828>,
#  'pondering': <gensim.models.keyedvectors.Vocab at 0x7f021c27d860>,
#  'sooner': <gensim.models.keyedvectors.Vocab at 0x7f021c27d898>,
#  'such': <gensim.models.keyedvectors.Vocab at 0x7f021c27d8d0>,
#  'quality': <gensim.models.keyedvectors.Vocab at 0x7f021c27d908>,
#  'flow': <gensim.models.keyedvectors.Vocab at 0x7f021c27d940>,
#  'odd': <gensim.models.keyedvectors.Vocab at 0x7f021c27d978>,
#  'hybrid': <gensim.models.keyedvectors.Vocab at 0x7f021c27d9b0>,
#  'anime': <gensim.models.keyedvectors.Vocab at 0x7f021c27d9e8>,
#  'area': <gensim.models.keyedvectors.Vocab at 0x7f021c27da20>,
#  'shines': <gensim.models.keyedvectors.Vocab at 0x7f021c27da58>,
#  'narrative': <gensim.models.keyedvectors.Vocab at 0x7f021c27da90>,
#  'enthralled': <gensim.models.keyedvectors.Vocab at 0x7f021c27dac8>,
#  'weaving': <gensim.models.keyedvectors.Vocab at 0x7f021c27db00>,
#  'diversity': <gensim.models.keyedvectors.Vocab at 0x7f021c27db38>,
#  'violent': <gensim.models.keyedvectors.Vocab at 0x7f021c27db70>,
#  'gory': <gensim.models.keyedvectors.Vocab at 0x7f021c27dba8>,
#  'encounter': <gensim.models.keyedvectors.Vocab at 0x7f021c27dbe0>,
#  'perhaps': <gensim.models.keyedvectors.Vocab at 0x7f021c27dc18>,
#  'contrasting': <gensim.models.keyedvectors.Vocab at 0x7f021c27dc50>,
#  'lighter': <gensim.models.keyedvectors.Vocab at 0x7f021c27dc88>,
#  'moment': <gensim.models.keyedvectors.Vocab at 0x7f021c27dcc0>,
#  'emotive': <gensim.models.keyedvectors.Vocab at 0x7f021c27dcf8>,
#  'bloodshed': <gensim.models.keyedvectors.Vocab at 0x7f021c27dd30>,
#  'bring': <gensim.models.keyedvectors.Vocab at 0x7f021c27dd68>,
#  'tears': <gensim.models.keyedvectors.Vocab at 0x7f021c27dda0>,
#  'combination': <gensim.models.keyedvectors.Vocab at 0x7f021c27ddd8>,
#  'where': <gensim.models.keyedvectors.Vocab at 0x7f021c27de10>,
#  'viewer': <gensim.models.keyedvectors.Vocab at 0x7f021c27de48>,
#  ...}

# %% [markdown]
# ### Get an embedding for a word

# %%
model.wv['flower']
# Out:
# array([-0.2856322 ,  1.8690357 ,  1.1131401 , -0.05964514, -1.2817084 ,
#         0.81716233, -0.40908554, -0.631256  , -1.0271999 ,  0.80576074,
#         1.0246943 , -0.8428521 ,  0.45067772,  0.41216603,  0.53160316,
#        -0.61579573, -1.4384805 , -0.3435652 ,  1.1133881 ,  0.39138207,
#        -0.17454813, -0.61728454,  0.36534303,  0.5923682 , -0.12844305,
#         0.9723035 , -0.19784941, -0.41993052, -0.9005013 ,  0.5294631 ,
#         1.1154263 , -0.40063667,  0.30552238, -0.37215015, -0.51981354,
#        -0.88963205, -1.028535  ,  0.41966107, -0.44275188,  0.30857357,
#         0.12868123,  1.098906  ,  0.2299486 ,  1.5636653 ,  0.09110276,
#         0.61304325, -0.23170473,  0.11386333,  0.30175668, -0.13751759],
#       dtype=float32)

# %% [markdown]
# ### Finding Words which have similar meaning

# %%
model.wv.most_similar('great')
# Out:
# 2018-11-03 07:43:49,411 : INFO : precomputing L2-norms of word weight vectors
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('terrific', 0.8819054961204529),
#  ('fantastic', 0.8809152841567993),
#  ('wonderful', 0.8730698823928833),
#  ('fine', 0.849142849445343),
#  ('good', 0.8334894776344299),
#  ('brilliant', 0.8108375668525696),
#  ('superb', 0.7947901487350464),
#  ('perfect', 0.7504172921180725),
#  ('nice', 0.7463917136192322),
#  ('amazing', 0.7434860467910767)]

# %% [markdown]
# ### Find the word which is not like others

# %%
model.doesnt_match("man woman child kitchen".split())
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `doesnt_match` (Method will be removed in 4.0.0, use self.wv.doesnt_match() instead).
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# 'kitchen'

# %% [markdown]
# ### Saving the model

# %%
model.save('word2vec-movie-50')

# %%
#Load model from memory
model = gensim.models.Word2Vec.load('word2vec-movie-50')

# %% [markdown]
# 1. Equation king + man = queen + ?
# 2. In this case there may not be enough data for this equation

# %%
model.most_similar(positive=['king','man'], negative=['queen'])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('prophecy', 0.5854490399360657),
#  ('soldier', 0.5454061627388),
#  ('scientist', 0.5230584740638733),
#  ('guy', 0.49423331022262573),
#  ('master', 0.4940657913684845),
#  ('enforcer', 0.4927676320075989),
#  ('seed', 0.48684585094451904),
#  ('freddy', 0.4807429313659668),
#  ('mercenary', 0.4800286591053009),
#  ('ryu', 0.4785825312137604)]
